# %% [markdown]
# # Bayesian Experimental Design for model selection

# %% [markdown]
# Script used to perform optimisation where a 4 step experiment is being design considering only the Bhattacharyya distance of GFP for the two models
#
#    ............................................................................................................................................................................................................................................

# %% [markdown]
# ### Import Required libraries

# %%
import numpy as np
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import seaborn as sns
from numba import jit
import gaussianprocess as gp
from fitderiv import fitderiv
import genutils as gu
import datetime
from bayes_opt import BayesianOptimization
from bayes_opt.observer import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs
import pickle

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import math

# %% [markdown]
# ### Model 1 Functions (ODEs, Steady State and Event based representation)
# * Lugagne et. al. Model

# %%
@jit
def model1(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    
    if u_IPTG > y[0]:
        dInd_dt[0]=k_in_IPTG*(u_IPTG-y[0])
    else:
        dInd_dt[0]=k_out_IPTG*(u_IPTG-y[0])
    
    if u_aTc > y[2]:
        dInd_dt[1]=k_in_aTc*(u_aTc-y[1])
    else:
        dInd_dt[1]=k_out_aTc*(u_aTc-y[1])
    
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState1(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode1(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState1(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model1,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 2 Functions (ODEs, Steady State and Event based representation)
# * Intermediate Model (Single rate, no degradation)

# %%
@jit
def model2(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0]);
    dInd_dt[1] = k_aTc*(u_aTc-y[1]);
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState2(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode2(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState2(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model2,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 3 Functions (ODEs, Steady State and Event based representation)
# * Lucia's Model

# %%
@jit
def model3(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0])-0.0165*y[0];
    dInd_dt[1] = k_aTc*(u_aTc-y[1])-0.0165*y[1];
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState3(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(4)
    alpha[0] = (k_IPTG*u_IPTG)/(k_IPTG+0.0165)
    alpha[1] = (k_aTc*u_aTc)/(k_aTc+0.0165)
    alpha[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(alpha[1]/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(alpha[0]/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode3(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    
    y_al = SteadyState3(p,ivss) # Calculation of initial guesses for steady state
    
    ssv = odeint(model3,y_al,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]
        
        
        
    
    return(final)

# %% [markdown]
# ### Functions to simulate the 3 models for all parameter draws

# %%
def solveALL (ts, pD, sp, inputs, ivss, pre, model):
    
    AllSol = np.empty((len(ts),len(pD[:,1])*2))
    AllSolTest = np.empty(((round(len(ts)/5)+1),len(pD[:,1])*2))
    for drawInd in range(0,len(pD[:,1])):
        
        p = pD[drawInd,:]
        if model == 'M1':
            temp = solve_coupled_ode1(ts, p, sp, inputs, ivss, pre)
        elif model == 'M2':
            temp = solve_coupled_ode2(ts, p, sp, inputs, ivss, pre)
        elif model == 'M3':
            temp = solve_coupled_ode3(ts, p, sp, inputs, ivss, pre)
        else:
            print('Please, select a correct model as M1, M2 or M3 for the desired one')

        AllSolTest[:,drawInd] = temp[:,2][::5]
        AllSolTest[:,drawInd+(len(pD[:,1]))] = temp[:,3][::5]

    return(AllSolTest)

# %% [markdown]
# ### Example:

# %%
ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
inputs = np.empty(18) # What needs to be optimised    --> example: [1e-7,100,1,1e-7]*4+[1e-7,100]
evnT = [int(i) for i in list(np.linspace(0,(24*60),10))]
t = np.linspace(0,(24*60),(24*60)+1)
pM3 = np.asarray(pd.read_csv("ParametersCSV/draws_ALL_Model3.stan.csv"))

# %%
p = pM3[0:5,:]
test = solveALL(t,p,evnT,[1e-7,100,1,1e-7]*4+[1e-7,100],ivss,pre, 'M3')
plt.figure()
plt.plot(t[::5], test[:,0:5], 'r')
plt.plot(t[::5], test[:,5:10], 'g')
plt.show()

# %% [markdown]
# ### Bhattacharyya distance function:

# %%
def BhattacharyyaDist (mu1, mu2, sd1, sd2):
    E = (sd1+sd2)/2
    Em1 = np.linalg.inv(E)
    dE = abs(np.linalg.det(E))

    t1 = np.matrix.transpose((np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))))
    t2 = np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))
    
    ft = (1/8)*t1*Em1*t2
    st = dE/np.sqrt(abs(np.linalg.det(sd1))*abs(np.linalg.det(sd2)))
    
    bhd = ft+0.5*np.log(st)
    
    return(float(bhd))

# %% [markdown]
# ### Definition of the utility function:

# %%
def utility2 (IPTG1, IPTG2, IPTG3, IPTG4,
             aTc1, aTc2, aTc3, aTc4):
    
    # Definition of inputs for the ODEs
        
    inputs = [round(IPTG1,2)+1e-7, int(aTc1)+1e-7, round(IPTG2,2)+1e-7, int(aTc2)+1e-7,
              round(IPTG3,2)+1e-7, int(aTc3)+1e-7, round(IPTG4,2)+1e-7, int(aTc4)+1e-7]
    
    # Initial values for steady state and inputs
    ivss = [1,1e-7,1363.193,28.510]
    pre = [1,1e-7]
    # Event switches and inputs
    sp = [int(i) for i in list(np.linspace(0,(24*60),5))]
    t =  np.linspace(0,(24*60),(24*60)+1)
    
    # load parameter draws for the two models
    pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
    pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))
    
    # Simulation of the system for the two models and extract of results
    solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
    solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')
    
    RFP_M1 = solM1[:,0:len(pM1[:,1])]
    GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]
    
    RFP_M2 = solM2[:,0:len(pM2[:,1])]
    GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]
    
    # Gaussian Process Regression and Reduction
    
    # Means and standard deviations for each time point for each species and for each model
    tgp = np.linspace(0,(24*60),round(24*60/5)+1)
    
#     muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
#     sdR3 = RFP_M2.std(axis = 1)
    muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
    sdG3 = GFP_M2.std(axis = 1)
#     muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
#     sdR2 = RFP_M1.std(axis = 1)
    muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
    sdG2 = GFP_M1.std(axis = 1)

    # Gaussian Process regression
#     gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
#     gR3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
#     gR3.predict(tgp)
    
    gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
    gG3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG3.predict(tgp)
    
#     gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
#     gR2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
#     gR2.predict(tgp)
    
    gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
    gG2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG2.predict(tgp)
    
    # Time points reduction

#     muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
#     tref = list(tgp[::10])

#     g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
#     g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
#     g2R3.predict(tref)

    
#     muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
#     tref = list(tgp[::10])

#     g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
#     g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
#     g2R2.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
    tref = list(tgp[::10])

    g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G3.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
    tref = list(tgp[::10])

    
    g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G2.predict(tref)

    
    # Bhattacharyya distance:
#     bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
    bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
    
    # Utility function value
    u_B = (bdG)

    return(u_B)

# %% [markdown]
# ### Bayesian Optimisation:

# %%
# Bounded region of parameter space

pbounds = {'IPTG1': (0, 1), 'IPTG2': (0, 1), 'IPTG3': (0, 1), 'IPTG4': (0, 1),
           'aTc1': (0, 100), 'aTc2': (0, 100), 'aTc3': (0, 100), 'aTc4': (0, 100)}

# %% [markdown]
# Setting Bayesian Optimisation with our utility function

# %%
optimizer3 = BayesianOptimization(
    f=utility2,
    pbounds=pbounds,
    verbose=2, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1324,
)

# %% [markdown]
# Begin optimisation rutine

# %%
optimizer3.maximize(
    init_points=0,
    n_iter=200,
    alpha=1e-2,
    n_restarts_optimizer=3, 
#     acq="ei", 
#     xi=1e-4
)
# Out:
# |   iter    |  target   |   IPTG1   |   IPTG2   |   IPTG3   |   IPTG4   |   aTc1    |   aTc2    |   aTc3    |   aTc4    |
# -------------------------------------------------------------------------------------------------------------------------
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 4
# |  805      |  4.665e+0 |  0.9336   |  0.465    |  0.2284   |  0.4382   |  47.37    |  18.65    |  23.4     |  8.882    |
# |  806      |  2.94e+03 |  0.8803   |  0.9154   |  0.1074   |  0.691    |  49.65    |  17.36    |  25.49    |  3.723    |
#  Warning: optimization failed at run 5
# |  807      |  1.556e+0 |  0.5555   |  0.2034   |  0.3964   |  0.506    |  51.5     |  19.57    |  25.7     |  11.52    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
# |  808      |  1.114e+0 |  0.9122   |  0.3365   |  0.6765   |  0.4441   |  49.18    |  27.97    |  18.29    |  9.351    |
#  Warning: optimization failed at run 8
# |  809      |  872.2    |  0.4355   |  0.2809   |  0.8188   |  0.01219  |  45.52    |  16.33    |  23.74    |  7.028    |
#  Warning: optimization failed at run 4
# |  810      |  7.079e+0 |  0.7794   |  0.3277   |  0.7957   |  0.8311   |  51.43    |  15.45    |  23.87    |  7.261    |
# |  811      |  6.17e+04 |  0.4928   |  0.712    |  0.526    |  0.7827   |  42.98    |  22.59    |  23.85    |  12.61    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 13
# |  812      |  1.244e+0 |  0.09806  |  0.7355   |  0.3786   |  0.03007  |  46.92    |  20.6     |  24.91    |  9.905    |
#  Warning: optimization failed at run 3
# |  813      |  7.287e+0 |  0.08498  |  0.7566   |  0.6186   |  0.3635   |  46.08    |  21.01    |  21.97    |  9.517    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
# |  814      |  3.246e+0 |  0.7188   |  0.4312   |  0.2433   |  0.3412   |  52.76    |  19.16    |  25.26    |  11.26    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
# |  815      |  9.224e+0 |  0.8797   |  0.8881   |  0.8778   |  0.4506   |  43.47    |  23.01    |  24.98    |  10.01    |
# |  816      |  4.927e+0 |  0.9078   |  0.6913   |  0.1631   |  0.7219   |  48.6     |  19.21    |  20.6     |  6.138    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 12
# |  817      |  1.309e+0 |  0.6236   |  0.1968   |  0.32     |  0.926    |  47.06    |  24.49    |  19.3     |  5.124    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
# |  818      |  7.764e+0 |  0.875    |  0.5873   |  0.6882   |  0.5631   |  34.21    |  30.03    |  75.35    |  1.151    |
#  Warning: optimization failed at run 8
# |  819      |  4.791e+0 |  0.9459   |  0.5806   |  0.6327   |  0.1293   |  47.7     |  24.74    |  19.64    |  3.488    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 14
# |  820      |  1.181e+0 |  0.0821   |  0.08903  |  0.9303   |  0.7044   |  50.92    |  20.02    |  27.4     |  16.39    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 11
# |  821      |  1.288e+0 |  0.347    |  0.6623   |  0.6884   |  0.2242   |  43.04    |  15.23    |  27.11    |  7.068    |
#  Warning: optimization failed at run 2
# |  822      |  1.207e+0 |  0.5522   |  0.783    |  0.6599   |  0.3604   |  35.99    |  32.48    |  74.08    |  2.29     |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
# |  823      |  2.244e+0 |  0.4743   |  0.4196   |  0.5835   |  0.549    |  55.3     |  29.03    |  16.16    |  4.696    |
# |  824      |  1.553e+0 |  0.7448   |  0.7624   |  0.8996   |  0.03369  |  46.04    |  24.04    |  20.23    |  5.673    |
#  Warning: optimization failed at run 14
# |  825      |  1.574e+0 |  0.5887   |  0.5416   |  0.6478   |  0.3166   |  49.08    |  27.07    |  17.7     |  8.798    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 13
# |  826      |  3.457e+0 |  0.6966   |  0.7926   |  0.7726   |  0.7809   |  45.72    |  20.15    |  26.52    |  9.787    |
#  Warning: optimization failed at run 11
# |  827      |  991.7    |  0.3515   |  0.8241   |  0.05635  |  0.5531   |  49.98    |  25.97    |  18.05    |  8.073    |
#  Warning: optimization failed at run 13
# |  828      |  2.318e+0 |  0.9501   |  0.7416   |  0.1622   |  0.3508   |  51.26    |  17.72    |  30.3     |  19.13    |
# |  829      |  1.774e+0 |  0.8084   |  0.5803   |  0.06046  |  0.8369   |  47.49    |  18.58    |  22.62    |  7.138    |
#  Warning: optimization failed at run 8
# |  830      |  1.468e+0 |  0.7268   |  0.9177   |  0.9483   |  0.5785   |  43.92    |  22.62    |  21.25    |  16.03    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
# |  831      |  242.7    |  0.1613   |  0.1183   |  0.2045   |  0.9169   |  50.57    |  21.85    |  28.27    |  18.46    |
#  Warning: optimization failed at run 6
# |  832      |  586.8    |  0.3983   |  0.511    |  0.1164   |  0.01187  |  57.65    |  26.53    |  11.9     |  12.68    |
#  Warning: optimization failed at run 14
# |  833      |  4.648e+0 |  0.108    |  0.9571   |  0.5779   |  0.3025   |  45.12    |  20.76    |  26.91    |  9.375    |
#  Warning: optimization failed at run 7
# |  834      |  1.694e+0 |  0.878    |  0.7132   |  0.873    |  0.3717   |  44.48    |  20.64    |  24.99    |  7.238    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 15
# |  835      |  2.037e+0 |  0.7808   |  0.2887   |  0.2021   |  0.4235   |  48.86    |  18.74    |  21.11    |  7.609    |
#  Warning: optimization failed at run 13
# |  836      |  7.574e+0 |  0.5633   |  0.3862   |  0.367    |  0.7904   |  43.36    |  21.64    |  25.87    |  12.73    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
# |  837      |  1.234e+0 |  0.5538   |  0.1421   |  0.5492   |  0.8515   |  45.12    |  20.4     |  23.71    |  9.457    |
#  Warning: optimization failed at run 11
# |  838      |  679.9    |  0.1194   |  0.1513   |  0.8662   |  0.8579   |  50.04    |  19.24    |  27.8     |  18.6     |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
# |  839      |  1.131e+0 |  0.7349   |  0.5442   |  0.8288   |  0.2876   |  55.84    |  29.1     |  14.21    |  4.111    |
#  Warning: optimization failed at run 6
# |  840      |  1.502e+0 |  0.5813   |  0.5348   |  0.832    |  0.3345   |  48.27    |  26.98    |  18.87    |  8.605    |
# |  841      |  9.456e+0 |  0.5014   |  0.8685   |  0.8712   |  0.9321   |  44.57    |  17.05    |  24.1     |  8.21     |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
# |  842      |  1.397e+0 |  0.8741   |  0.7586   |  0.6835   |  0.7571   |  45.28    |  21.28    |  26.97    |  10.54    |
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 10
# |  843      |  1.02e+04 |  0.3655   |  0.4803   |  0.8606   |  0.343    |  43.68    |  23.96    |  23.82    |  12.65    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
# |  844      |  702.7    |  0.1687   |  0.2013   |  0.9181   |  0.5327   |  50.15    |  18.5     |  28.58    |  16.93    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 7
# |  845      |  1.277e+0 |  0.4152   |  0.4545   |  0.2928   |  0.8179   |  49.01    |  17.29    |  25.13    |  7.455    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 14
# |  846      |  503.8    |  0.7666   |  0.4918   |  0.8087   |  0.1868   |  35.16    |  33.05    |  75.55    |  4.257    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
# |  847      |  1.302e+0 |  0.8923   |  0.6564   |  0.9355   |  0.3398   |  48.27    |  17.15    |  21.37    |  6.222    |
#  Warning: optimization failed at run 3
# |  848      |  4.404e+0 |  0.8245   |  0.8954   |  0.7109   |  0.4546   |  44.06    |  21.73    |  21.72    |  10.52    |
# |  849      |  3.587e+0 |  0.9049   |  0.888    |  0.43     |  0.7661   |  45.53    |  16.18    |  24.87    |  9.728    |
#  Warning: optimization failed at run 11
# |  850      |  3.1e+04  |  0.9838   |  0.6258   |  0.7182   |  0.5543   |  46.05    |  18.2     |  24.96    |  6.316    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 10
# |  851      |  1.324e+0 |  0.7759   |  0.1342   |  0.9184   |  0.9892   |  49.02    |  18.82    |  20.58    |  6.77     |
#  Warning: optimization failed at run 15
# |  852      |  1.064e+0 |  0.1419   |  0.6583   |  0.9302   |  0.8394   |  40.91    |  23.9     |  24.45    |  12.08    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 14
# |  853      |  1.757e+0 |  0.7992   |  0.1455   |  0.4081   |  0.5115   |  54.99    |  26.61    |  13.83    |  14.59    |
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
# |  854      |  2.306e+0 |  0.3441   |  0.7257   |  0.8839   |  0.9808   |  52.14    |  19.41    |  28.06    |  16.07    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 1
# |  855      |  305.8    |  0.1778   |  0.1181   |  0.3373   |  0.228    |  50.01    |  27.25    |  30.61    |  50.19    |
#  Warning: optimization failed at run 3
# |  856      |  5.26e+04 |  0.4917   |  0.9335   |  0.8831   |  0.7727   |  52.93    |  19.15    |  28.92    |  11.22    |
#  Warning: optimization failed at run 10
# |  857      |  249.4    |  0.789    |  0.1239   |  0.03846  |  0.2664   |  53.34    |  24.53    |  11.78    |  11.01    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
# |  858      |  2.909e+0 |  0.9839   |  0.8921   |  0.1426   |  0.2407   |  48.67    |  18.99    |  21.98    |  8.172    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
# |  859      |  3.714e+0 |  0.9704   |  0.6042   |  0.7405   |  0.719    |  46.43    |  18.82    |  24.33    |  8.366    |
#  Warning: optimization failed at run 5
# |  860      |  5.957e+0 |  0.1929   |  0.9944   |  0.5279   |  0.1567   |  46.43    |  16.44    |  24.74    |  4.933    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 14
# |  861      |  5.56e+03 |  0.928    |  0.2776   |  0.6145   |  0.5219   |  46.9     |  18.47    |  22.99    |  5.816    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
# |  862      |  1.137e+0 |  0.8019   |  0.8089   |  0.4766   |  0.8759   |  33.25    |  30.7     |  74.68    |  3.914    |
#  Warning: optimization failed at run 9
# |  863      |  1.163e+0 |  0.8059   |  0.9706   |  0.024    |  0.6935   |  44.76    |  23.09    |  24.06    |  13.1     |
#  Warning: optimization failed at run 12
# |  864      |  646.1    |  0.5869   |  0.4239   |  0.649    |  0.2155   |  33.7     |  32.43    |  75.46    |  4.476    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 6
# |  865      |  2.319e+0 |  0.1976   |  0.1864   |  0.5003   |  0.7678   |  46.25    |  19.72    |  27.16    |  10.36    |
# |  866      |  861.3    |  0.7322   |  0.2578   |  0.03183  |  0.3246   |  49.85    |  17.43    |  22.49    |  6.793    |
# |  867      |  1.588e+0 |  0.9993   |  0.8358   |  0.6519   |  0.7323   |  52.44    |  24.61    |  15.48    |  11.94    |
#  Warning: optimization failed at run 13
# |  868      |  1.808e+0 |  0.002861 |  0.8535   |  0.6784   |  0.4962   |  57.69    |  27.45    |  12.94    |  12.68    |
#  Warning: optimization failed at run 13
# |  869      |  431.7    |  0.5333   |  0.02522  |  0.3459   |  0.336    |  52.09    |  18.15    |  27.41    |  12.12    |
#  Warning: optimization failed at run 9
# |  870      |  7.599e+0 |  0.5733   |  0.9917   |  0.802    |  0.5981   |  52.89    |  25.06    |  16.09    |  12.84    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
# |  871      |  1.92e+04 |  0.5494   |  0.5849   |  0.4236   |  0.2586   |  51.29    |  25.74    |  15.18    |  12.26    |
# |  872      |  643.9    |  0.8593   |  0.09555  |  0.3721   |  0.9867   |  47.79    |  23.79    |  19.57    |  4.563    |
# |  873      |  1.293e+0 |  0.4112   |  0.1906   |  0.8642   |  0.3297   |  49.14    |  18.17    |  25.39    |  8.493    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 3
# |  874      |  829.4    |  0.2253   |  0.6787   |  0.02285  |  0.4609   |  44.11    |  18.96    |  27.0     |  9.909    |
# |  875      |  1.545e+0 |  0.3913   |  0.1629   |  0.3791   |  0.7508   |  46.36    |  17.7     |  26.09    |  6.847    |
#  Warning: optimization failed at run 14
# |  876      |  1.936e+0 |  0.6556   |  0.5572   |  0.07496  |  0.3229   |  43.54    |  24.09    |  21.83    |  16.68    |
# |  877      |  1.074e+0 |  0.5713   |  0.05962  |  0.597    |  0.7157   |  45.72    |  24.95    |  19.5     |  6.57     |
#  Warning: optimization failed at run 11
# |  878      |  9.243e+0 |  0.934    |  0.4951   |  0.5086   |  0.3207   |  51.43    |  17.04    |  25.48    |  11.39    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 2
# |  879      |  4.621e+0 |  0.9694   |  0.3377   |  0.65     |  0.7041   |  44.83    |  22.75    |  25.82    |  10.34    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
# |  880      |  1.042e+0 |  0.5847   |  0.6365   |  0.2487   |  0.6049   |  48.14    |  19.92    |  23.61    |  5.915    |
#  Warning: optimization failed at run 11
# |  881      |  1.153e+0 |  0.2273   |  0.2571   |  0.1402   |  0.08214  |  43.22    |  22.43    |  23.84    |  13.07    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
# |  882      |  7.408e+0 |  0.957    |  0.805    |  0.9654   |  0.2461   |  48.01    |  17.2     |  23.24    |  6.356    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 1
# |  883      |  5.033e+0 |  0.856    |  0.7468   |  0.6951   |  0.4187   |  46.87    |  22.48    |  18.45    |  4.228    |
# |  884      |  5.631e+0 |  0.4432   |  0.3211   |  0.9915   |  0.9679   |  48.73    |  24.96    |  18.63    |  8.435    |
#  Warning: optimization failed at run 1
# |  885      |  391.8    |  0.1491   |  0.05412  |  0.04411  |  0.8326   |  44.73    |  21.88    |  27.5     |  9.856    |
# |  886      |  1.925e+0 |  0.2679   |  0.719    |  0.6206   |  0.6612   |  47.28    |  25.21    |  19.53    |  4.151    |
# |  887      |  1.128e+0 |  0.7033   |  0.18     |  0.2845   |  0.8479   |  48.6     |  17.91    |  23.32    |  6.581    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 10
# |  888      |  258.1    |  0.01097  |  0.2236   |  0.2934   |  0.04308  |  44.61    |  21.43    |  26.94    |  10.08    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 9
# |  889      |  1.412e+0 |  0.9084   |  0.989    |  0.996    |  0.5834   |  48.7     |  23.85    |  20.73    |  4.203    |
#  Warning: optimization failed at run 13
# |  890      |  448.9    |  0.181    |  0.3424   |  0.6794   |  0.03691  |  51.13    |  18.55    |  26.44    |  16.59    |
# |  891      |  2.573e+0 |  0.3129   |  0.6057   |  0.925    |  0.6835   |  51.55    |  18.98    |  23.95    |  9.549    |
#  Warning: optimization failed at run 5
# |  892      |  1.856e+0 |  0.9115   |  0.8174   |  0.6441   |  0.5471   |  48.5     |  17.83    |  22.53    |  6.515    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 12
# |  893      |  7.705e+0 |  0.232    |  0.4379   |  0.9891   |  0.63     |  46.2     |  20.0     |  26.95    |  9.054    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 2
# |  894      |  5.823e+0 |  0.06406  |  0.5424   |  0.5276   |  0.6817   |  50.42    |  17.18    |  24.67    |  11.58    |
# |  895      |  1.23e+03 |  0.4343   |  0.1747   |  0.7968   |  0.4987   |  51.19    |  15.82    |  24.94    |  16.33    |
#  Warning: optimization failed at run 9
# |  896      |  2.625e+0 |  0.8971   |  0.6519   |  0.5793   |  0.8603   |  51.58    |  18.05    |  26.72    |  12.84    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
# |  897      |  1.158e+0 |  0.5948   |  0.6922   |  0.05966  |  0.005213 |  44.48    |  21.14    |  26.57    |  10.31    |
#  Warning: optimization failed at run 14
# |  898      |  2.209e+0 |  0.001497 |  0.804    |  0.1836   |  0.8559   |  50.59    |  16.08    |  24.54    |  13.33    |
# |  899      |  1.033e+0 |  0.6637   |  0.1752   |  0.3739   |  0.97     |  51.36    |  17.33    |  26.37    |  7.539    |
#  Warning: optimization failed at run 6
# |  900      |  8.762e+0 |  0.6537   |  0.8833   |  0.2933   |  0.324    |  51.65    |  17.97    |  28.51    |  15.8     |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
# |  901      |  9.461e+0 |  0.7141   |  0.8702   |  0.4254   |  0.1493   |  47.93    |  23.18    |  18.18    |  5.522    |
#  Warning: optimization failed at run 14
# |  902      |  924.8    |  0.9691   |  0.913    |  0.00409  |  0.7229   |  52.77    |  18.7     |  30.12    |  12.09    |
#  Warning: optimization failed at run 3
# |  903      |  4.209e+0 |  0.2963   |  0.7033   |  0.2841   |  0.6484   |  55.28    |  28.74    |  15.38    |  4.271    |
# |  904      |  788.8    |  0.2305   |  0.05613  |  0.3164   |  0.3848   |  44.97    |  21.64    |  24.14    |  10.47    |
#  Warning: optimization failed at run 3
# |  905      |  2.182e+0 |  0.0714   |  0.9726   |  0.2672   |  0.7033   |  45.29    |  21.44    |  23.42    |  12.32    |
#  Warning: optimization failed at run 15
# |  906      |  806.0    |  0.3912   |  0.3072   |  0.03933  |  0.7574   |  44.34    |  21.3     |  20.51    |  11.07    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
# |  907      |  452.1    |  0.4854   |  0.04889  |  0.518    |  0.9015   |  54.21    |  18.99    |  30.05    |  10.77    |
# |  908      |  521.4    |  0.9695   |  0.1502   |  0.5234   |  0.6277   |  31.7     |  32.52    |  76.54    |  2.887    |
# |  909      |  202.3    |  0.9436   |  0.01574  |  0.06983  |  0.2677   |  51.9     |  18.53    |  25.94    |  13.76    |
# |  910      |  4.703e+0 |  0.1868   |  0.6108   |  0.8244   |  0.1776   |  53.18    |  23.07    |  12.32    |  11.18    |
#  Warning: optimization failed at run 7
# |  911      |  3.464e+0 |  0.3511   |  0.645    |  0.225    |  0.2296   |  50.96    |  20.03    |  29.3     |  19.04    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
# |  912      |  3.685e+0 |  0.9151   |  0.7775   |  0.2181   |  0.09822  |  49.05    |  28.72    |  17.41    |  10.43    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 12
# |  913      |  8.063e+0 |  0.4928   |  0.8823   |  0.2786   |  0.8981   |  47.36    |  18.2     |  25.99    |  5.657    |
#  Warning: optimization failed at run 4
# |  914      |  762.3    |  0.8187   |  0.1392   |  0.4608   |  0.1633   |  48.27    |  17.88    |  25.93    |  4.782    |
#  Warning: optimization failed at run 3
# |  915      |  2.122e+0 |  0.3914   |  0.5342   |  0.7129   |  0.3593   |  45.78    |  19.8     |  23.45    |  10.77    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
# |  916      |  720.3    |  0.02187  |  0.06958  |  0.215    |  0.541    |  51.01    |  18.82    |  27.89    |  16.46    |
#  Warning: optimization failed at run 13
# |  917      |  5.78e+03 |  0.4699   |  0.6584   |  0.2052   |  0.5964   |  46.38    |  20.89    |  23.11    |  10.66    |
#  Warning: optimization failed at run 11
# |  918      |  252.9    |  0.1494   |  0.5847   |  0.9814   |  0.1401   |  33.68    |  32.48    |  76.42    |  6.342    |
# |  919      |  1.508e+0 |  0.8835   |  0.5882   |  0.06571  |  0.9873   |  43.0     |  23.66    |  21.52    |  9.923    |
# |  920      |  1.1e+03  |  0.9031   |  0.8336   |  0.03499  |  0.6781   |  50.81    |  19.35    |  28.52    |  19.73    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
# |  921      |  1.246e+0 |  0.7138   |  0.9045   |  0.2653   |  0.7327   |  46.78    |  15.76    |  25.36    |  6.345    |
#  Warning: optimization failed at run 6
# |  922      |  975.8    |  0.6879   |  0.1646   |  0.3395   |  0.9899   |  42.8     |  21.4     |  24.53    |  7.049    |
#  Warning: optimization failed at run 15
# |  923      |  4.356e+0 |  0.472    |  0.9005   |  0.8927   |  0.9691   |  51.84    |  20.21    |  29.93    |  18.87    |
#  Warning: optimization failed at run 10
# |  924      |  1.427e+0 |  0.9562   |  0.1304   |  0.7255   |  0.8098   |  45.41    |  14.11    |  26.64    |  10.52    |
#  Warning: optimization failed at run 4
# |  925      |  1.509e+0 |  0.4775   |  0.1608   |  0.4503   |  0.6378   |  48.06    |  19.36    |  25.64    |  5.616    |
#  Warning: optimization failed at run 15
# |  926      |  1.645e+0 |  0.2174   |  0.5711   |  0.1533   |  0.5636   |  55.01    |  31.13    |  14.44    |  3.31     |
#  Warning: optimization failed at run 13
# |  927      |  1.361e+0 |  0.575    |  0.8121   |  0.298    |  0.7407   |  54.18    |  25.32    |  14.21    |  10.72    |
#  Warning: optimization failed at run 7
# |  928      |  4.504e+0 |  0.4839   |  0.8105   |  0.6038   |  0.8369   |  45.32    |  20.96    |  28.78    |  9.735    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
# |  929      |  2.458e+0 |  0.3103   |  0.4953   |  0.5872   |  0.6867   |  45.63    |  21.12    |  30.65    |  7.957    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
# |  930      |  8.85e+03 |  0.7789   |  0.7853   |  0.2675   |  0.274    |  49.73    |  25.1     |  18.14    |  3.99     |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
# |  931      |  1.448e+0 |  0.4483   |  0.3703   |  0.9145   |  0.804    |  45.88    |  20.18    |  23.85    |  10.57    |
# |  932      |  1.114e+0 |  0.4579   |  0.1508   |  0.4293   |  0.2562   |  45.03    |  16.85    |  25.31    |  10.12    |
# |  933      |  4.112e+0 |  0.9853   |  0.3867   |  0.939    |  0.2411   |  43.79    |  22.65    |  21.7     |  10.01    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
# |  934      |  1.408e+0 |  0.7779   |  0.6871   |  0.843    |  0.5959   |  32.55    |  32.3     |  75.85    |  5.685    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 15
# |  935      |  3.606e+0 |  0.6324   |  0.7577   |  0.1333   |  0.4815   |  48.24    |  23.82    |  20.78    |  2.895    |
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 12
# |  936      |  1.301e+0 |  0.1797   |  0.2927   |  0.1866   |  0.9608   |  45.99    |  14.92    |  24.01    |  11.07    |
# |  937      |  455.9    |  0.6103   |  0.1843   |  0.07791  |  0.9179   |  45.65    |  19.39    |  26.55    |  8.857    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  938      |  1.199e+0 |  0.2183   |  0.7696   |  0.8317   |  0.4833   |  46.71    |  20.53    |  28.69    |  9.908    |
#  Warning: optimization failed at run 6
# |  939      |  2.042e+0 |  0.7491   |  0.2028   |  0.7296   |  0.8408   |  42.84    |  22.21    |  24.97    |  11.81    |
#  Warning: optimization failed at run 6
# |  940      |  8.272e+0 |  0.5372   |  0.8673   |  0.2345   |  0.5569   |  48.76    |  19.28    |  22.15    |  6.514    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 2
# |  941      |  5.291e+0 |  0.8087   |  0.421    |  0.2985   |  0.9417   |  43.9     |  18.22    |  24.18    |  8.476    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
# |  942      |  1.17e+03 |  0.6397   |  0.3542   |  0.07316  |  0.4786   |  45.13    |  20.19    |  25.5     |  8.341    |
#  Warning: optimization failed at run 9
# |  943      |  9.666e+0 |  0.5162   |  0.7802   |  0.5269   |  0.139    |  41.96    |  19.64    |  23.12    |  11.48    |
# |  944      |  4.741e+0 |  0.576    |  0.9309   |  0.5076   |  0.06121  |  45.55    |  21.2     |  29.7     |  10.3     |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
# |  945      |  4.498e+0 |  0.6375   |  0.5309   |  0.8587   |  0.8778   |  44.78    |  20.97    |  23.82    |  10.54    |
# |  946      |  733.7    |  0.4463   |  0.1246   |  0.4765   |  0.6485   |  52.25    |  19.16    |  27.78    |  11.68    |
# |  947      |  8.639e+0 |  0.5056   |  0.3359   |  0.488    |  0.7915   |  45.37    |  20.18    |  25.66    |  9.805    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
# |  948      |  589.2    |  0.3253   |  0.02331  |  0.9067   |  0.8424   |  47.44    |  17.91    |  26.6     |  5.407    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
# |  949      |  6.754e+0 |  0.4707   |  0.9977   |  0.8152   |  0.7166   |  44.22    |  21.68    |  23.68    |  11.64    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
# |  950      |  5.433e+0 |  0.4738   |  0.2631   |  0.7627   |  0.6624   |  43.68    |  21.32    |  24.48    |  9.007    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
# |  951      |  2.385e+0 |  0.9021   |  0.4768   |  0.6566   |  0.8459   |  45.03    |  16.69    |  23.71    |  8.615    |
#  Warning: optimization failed at run 1
# |  952      |  1.301e+0 |  0.6962   |  0.4471   |  0.9106   |  0.4529   |  46.8     |  22.69    |  18.95    |  3.9      |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
# |  953      |  593.3    |  0.2171   |  0.1136   |  0.4125   |  0.2029   |  50.87    |  18.14    |  26.29    |  18.08    |
#  Warning: optimization failed at run 15
# |  954      |  7.283e+0 |  0.7712   |  0.8006   |  0.6139   |  0.583    |  52.36    |  18.94    |  28.04    |  9.315    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 3
# |  955      |  5.119e+0 |  0.1261   |  0.3958   |  0.8092   |  0.7023   |  52.98    |  19.07    |  28.15    |  8.364    |
# |  956      |  1.991e+0 |  0.8849   |  0.7394   |  0.9847   |  0.4101   |  45.35    |  25.86    |  20.1     |  6.046    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 11
# |  957      |  2.821e+0 |  0.9605   |  0.579    |  0.7341   |  0.8823   |  50.71    |  17.22    |  25.52    |  10.39    |
#  Warning: optimization failed at run 2
# |  958      |  4.491e+0 |  0.1094   |  0.3321   |  0.5833   |  0.6522   |  51.96    |  18.96    |  25.91    |  17.88    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
# |  959      |  1.078e+0 |  0.8033   |  0.4493   |  0.7674   |  0.3701   |  48.88    |  24.49    |  21.71    |  8.181    |
#  Warning: optimization failed at run 2
# |  960      |  4.673e+0 |  0.6836   |  0.2416   |  0.5226   |  0.9768   |  53.15    |  23.98    |  13.65    |  12.17    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
# |  961      |  1.458e+0 |  0.6628   |  0.1305   |  0.469    |  0.5554   |  57.45    |  27.95    |  16.12    |  9.038    |
#  Warning: optimization failed at run 7
# |  962      |  4.816e+0 |  0.9698   |  0.888    |  0.8878   |  0.5291   |  46.84    |  24.76    |  19.74    |  4.992    |
# |  963      |  2.749e+0 |  0.3807   |  0.1826   |  0.6984   |  0.8391   |  44.22    |  17.41    |  24.89    |  8.204    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 4
# |  964      |  3.347e+0 |  0.8133   |  0.6355   |  0.6833   |  0.7962   |  45.26    |  20.69    |  30.58    |  8.937    |
# |  965      |  9.019e+0 |  0.5525   |  0.6612   |  0.2625   |  0.5418   |  56.92    |  26.66    |  13.1     |  12.96    |
#  Warning: optimization failed at run 15
# |  966      |  2.445e+0 |  0.4877   |  0.2221   |  0.3316   |  0.665    |  44.15    |  22.34    |  22.39    |  11.94    |
#  Warning: optimization failed at run 4
# |  967      |  8.261e+0 |  0.1118   |  0.8128   |  0.6951   |  0.8163   |  50.27    |  19.65    |  23.34    |  8.769    |
#  Warning: optimization failed at run 3
# |  968      |  1.797e+0 |  0.2582   |  0.342    |  0.6815   |  0.1985   |  52.14    |  15.68    |  24.6     |  17.55    |
#  Warning: optimization failed at run 1
# |  969      |  3.647e+0 |  0.8887   |  0.3064   |  0.7215   |  0.8584   |  44.24    |  20.16    |  28.27    |  9.775    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 9
# |  970      |  1.543e+0 |  0.8839   |  0.9912   |  0.1237   |  0.4501   |  32.82    |  32.96    |  76.35    |  3.361    |
#  Warning: optimization failed at run 1
# |  971      |  1.655e+0 |  0.7146   |  0.8279   |  0.6731   |  0.9874   |  50.11    |  18.67    |  23.22    |  9.802    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
# |  972      |  4.171e+0 |  0.1429   |  0.9589   |  0.8729   |  0.8472   |  55.67    |  29.45    |  13.88    |  5.072    |
# |  973      |  1.237e+0 |  0.3708   |  0.8081   |  0.4341   |  0.2863   |  52.97    |  24.2     |  16.73    |  13.02    |
# |  974      |  1.79e+04 |  0.3821   |  0.5087   |  0.4696   |  0.8669   |  51.51    |  17.75    |  28.23    |  10.5     |
#  Warning: optimization failed at run 3
# |  975      |  5.868e+0 |  0.2073   |  0.9758   |  0.3859   |  0.4964   |  48.86    |  29.37    |  18.26    |  9.388    |
#  Warning: optimization failed at run 15
# |  976      |  1.187e+0 |  0.4421   |  0.9903   |  0.5186   |  0.2694   |  46.64    |  21.24    |  29.54    |  7.778    |
# |  977      |  1.225e+0 |  0.8643   |  0.9017   |  0.7424   |  0.6925   |  53.92    |  27.6     |  14.55    |  14.0     |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
# |  978      |  1.603e+0 |  0.8037   |  0.6601   |  0.7422   |  0.7596   |  44.99    |  17.67    |  23.37    |  8.021    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 13
# |  979      |  6.199e+0 |  0.1716   |  0.4543   |  0.4401   |  0.4825   |  51.15    |  19.42    |  26.03    |  12.52    |
# |  980      |  2.423e+0 |  0.9509   |  0.4289   |  0.1858   |  0.7591   |  45.42    |  20.83    |  24.81    |  10.89    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
# |  981      |  6.17e+03 |  0.06132  |  0.2972   |  0.8609   |  0.9486   |  53.46    |  27.98    |  13.81    |  12.67    |
#  Warning: optimization failed at run 1
# |  982      |  1.434e+0 |  0.589    |  0.8343   |  0.4064   |  0.6077   |  52.15    |  18.49    |  28.69    |  21.16    |
#  Warning: optimization failed at run 2
# |  983      |  2.258e+0 |  0.5691   |  0.674    |  0.8122   |  0.4107   |  45.15    |  17.01    |  23.36    |  5.781    |
# |  984      |  1.015e+0 |  0.04983  |  0.4514   |  0.1488   |  0.9916   |  50.5     |  26.05    |  15.63    |  13.08    |
#  Warning: optimization failed at run 4
# |  985      |  1.111e+0 |  0.6814   |  0.967    |  0.874    |  0.8872   |  46.58    |  21.68    |  28.48    |  10.5     |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
# |  986      |  1.016e+0 |  0.009065 |  0.148    |  0.4822   |  0.5892   |  53.34    |  21.61    |  30.21    |  11.99    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
# |  987      |  1.499e+0 |  0.259    |  0.9687   |  0.8205   |  0.5817   |  56.47    |  28.26    |  13.4     |  15.02    |
#  Warning: optimization failed at run 10
# |  988      |  1.939e+0 |  0.09703  |  0.7307   |  0.7472   |  0.4926   |  34.21    |  30.47    |  74.43    |  2.081    |
# |  989      |  2.654e+0 |  0.3449   |  0.6925   |  0.1662   |  0.7754   |  56.5     |  28.29    |  13.22    |  13.95    |
#  Warning: optimization failed at run 6
# |  990      |  1.043e+0 |  0.4064   |  0.5919   |  0.8942   |  0.4069   |  50.91    |  19.21    |  28.94    |  17.12    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
# |  991      |  1.391e+0 |  0.1754   |  0.7032   |  0.69     |  0.6255   |  48.83    |  17.23    |  26.04    |  7.676    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
# |  992      |  962.1    |  0.1048   |  0.9041   |  0.1103   |  0.6007   |  52.87    |  18.64    |  28.72    |  9.683    |
# |  993      |  1.967e+0 |  0.8415   |  0.8696   |  0.5492   |  0.2453   |  44.58    |  20.32    |  31.0     |  10.05    |
# |  994      |  5.31e+03 |  0.3399   |  0.8702   |  0.2734   |  0.7448   |  50.27    |  18.74    |  23.86    |  10.56    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
# |  995      |  5.991e+0 |  0.5784   |  0.5294   |  0.7811   |  0.7833   |  48.9     |  18.46    |  22.12    |  8.995    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
# |  996      |  247.8    |  0.8254   |  0.04741  |  0.1167   |  0.8182   |  47.49    |  21.07    |  28.22    |  8.458    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
# |  997      |  1.164e+0 |  0.4835   |  0.5135   |  0.3289   |  0.9056   |  47.68    |  17.32    |  27.41    |  6.313    |
#  Warning: optimization failed at run 3
# |  998      |  4.32e+04 |  0.4978   |  0.8683   |  0.5128   |  0.5626   |  56.02    |  28.0     |  12.31    |  15.24    |
# |  999      |  5.177e+0 |  0.007574 |  0.9104   |  0.6669   |  0.7591   |  47.85    |  26.88    |  20.6     |  10.14    |
#  Warning: optimization failed at run 2
# |  1000     |  3.413e+0 |  0.4858   |  0.6605   |  0.386    |  0.9583   |  53.91    |  28.43    |  15.22    |  15.05    |
# |  1001     |  1.873e+0 |  0.7969   |  0.4712   |  0.4051   |  0.361    |  43.28    |  16.09    |  23.67    |  7.602    |
#  Warning: optimization failed at run 8
# |  1002     |  2.871e+0 |  0.4419   |  0.9279   |  0.179    |  0.6631   |  51.14    |  19.43    |  25.04    |  12.32    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 3
# |  1003     |  5.042e+0 |  0.5093   |  0.7224   |  0.7418   |  0.457    |  47.69    |  18.29    |  26.65    |  6.929    |
# |  1004     |  671.7    |  0.9598   |  0.1097   |  0.5004   |  0.8737   |  52.14    |  19.64    |  28.27    |  8.928    |
# =========================================================================================================================

# %%
# Save results obtained
with open('config4sGFP3.optim', 'wb') as config_optim_file:
 
    pickle.dump(optimizer3, config_optim_file)

# %%
# Best utility value generated
print(optimizer3.max)
# Out:
# {'target': 345701.2713790903, 'params': {'IPTG1': 0.696577619516928, 'IPTG2': 0.7925533501325704, 'IPTG3': 0.7726398005081347, 'IPTG4': 0.7809315639053528, 'aTc1': 45.71975819364901, 'aTc2': 20.15450644105583, 'aTc3': 26.518686206304942, 'aTc4': 9.786815582017127}}

# %% [markdown]
# Plot best utility value so far per iteration:

# %%
v = []
for i, res in enumerate(optimizer3.res):
    v.append(res['target'])
    
vn = []
for i, val in enumerate(v):
    mv = max(v[0:i+1])
    vn.append(mv)
    
plt.figure()
plt.plot(vn)
plt.plot(v)
plt.show()

# %%
df = pd.DataFrame({
    'CFV': v})
df.to_csv('CFV_Iter_4S_GFP.csv')

df = pd.DataFrame({
    'CFV': vn})
df.to_csv('bestCFV_Iter_4S_GFP.csv')

# %% [markdown]
# ### Check results with plot

# %%
inputs = [round(optimizer3.max['params']['IPTG1'], 2)+1e-7, int(optimizer3.max['params']['aTc1'])+1e-7, 
          round(optimizer3.max['params']['IPTG2'], 2)+1e-7, int(optimizer3.max['params']['aTc2'])+1e-7, 
          round(optimizer3.max['params']['IPTG3'], 2)+1e-7, int(optimizer3.max['params']['aTc3'])+1e-7, 
          round(optimizer3.max['params']['IPTG4'], 2)+1e-7, int(optimizer3.max['params']['aTc4'])+1e-7]

ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
sp = [int(i) for i in list(np.linspace(0,(24*60),5))]
t =  np.linspace(0,(24*60),(24*60)+1)

pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))

# Simulation of the system for the two models and extract of results
solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')

RFP_M1 = solM1[:,0:len(pM1[:,1])]
GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]

RFP_M2 = solM2[:,0:len(pM2[:,1])]
GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]

# %%
t = np.linspace(0,(24*60),round(24*60/5)+1)

plt.figure()
lines = plt.plot(t, GFP_M2, 'c')
plt.text((24*60)+1, 800, "Model 2", bbox=dict(facecolor='c'))
plt.title("Average")
lines2 = plt.plot(t, GFP_M1, 'g')
plt.text((24*60)+1, 600, "Model 1", bbox=dict(facecolor='g'))

plt.show()
plt.figure()
plt.plot(t, RFP_M2, 'c')

plt.text((24*60)+1, 500, "Model 2", bbox=dict(facecolor='c'))
plt.text((24*60)+1, 40, "Model 1", bbox=dict(facecolor='r'))
plt.plot(t, RFP_M1, 'r')
plt.show()

# %% [markdown]
# ### Check utility decomposition results

# %%
# Gaussian Process Regression and Reduction

# Means and standard deviations for each time point for each species and for each model
tgp = np.linspace(0,(24*60),(24*60/5)+1)

muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
sdR3 = RFP_M2.std(axis = 1)
muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
sdG3 = GFP_M2.std(axis = 1)
muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
sdR2 = RFP_M1.std(axis = 1)
muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
sdG2 = GFP_M1.std(axis = 1)

# Gaussian Process regression
gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
gR3.findhyperparameters(noruns=15)
gR3.predict(tgp)

gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
gG3.findhyperparameters(noruns=15)
gG3.predict(tgp)

gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
gR2.findhyperparameters(noruns=15)
gR2.predict(tgp)

gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
gG2.findhyperparameters(noruns=15)
gG2.predict(tgp)

# %%
muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R2.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G2.predict(tref)

# %%
bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
u_B = (bdR*bdG)

# %%
print("The BD for RFP is: ", str(bdR))
print("The BD for GFP is: ", str(bdG))
print("The multiplicative BD is: ", str(u_B))
print("The average BD is: ", str((bdR+bdG)/2))
