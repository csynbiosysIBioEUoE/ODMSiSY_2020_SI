# %% [markdown]
# # Bayesian Experimental Design for model selection

# %% [markdown]
# Script used to perform Bayesian Experimental Design for model selection where 2 steps for the inputs are considered and the utility function considers the Bhattacharyya distance of GFP for the two models
#
#    ............................................................................................................................................................................................................................................

# %% [markdown]
# ### Import Required libraries

# %%
import numpy as np
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import seaborn as sns
from numba import jit
import gaussianprocess as gp
from fitderiv import fitderiv
import genutils as gu
import datetime
from bayes_opt import BayesianOptimization
from bayes_opt.observer import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs
import pickle

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import math

# %% [markdown]
# ### Model 1 Functions (ODEs, Steady State and Event based representation)
# * Lugagne et. al. Model

# %%
@jit
def model1(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    
    if u_IPTG > y[0]:
        dInd_dt[0]=k_in_IPTG*(u_IPTG-y[0])
    else:
        dInd_dt[0]=k_out_IPTG*(u_IPTG-y[0])
    
    if u_aTc > y[2]:
        dInd_dt[1]=k_in_aTc*(u_aTc-y[1])
    else:
        dInd_dt[1]=k_out_aTc*(u_aTc-y[1])
    
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState1(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode1(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState1(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model1,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 2 Functions (ODEs, Steady State and Event based representation)
# * Intermediate Model (Single rate, no degradation)

# %%
@jit
def model2(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0]);
    dInd_dt[1] = k_aTc*(u_aTc-y[1]);
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState2(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode2(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState2(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model2,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 3 Functions (ODEs, Steady State and Event based representation)
# * Lucia's Model

# %%
@jit
def model3(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0])-0.0165*y[0];
    dInd_dt[1] = k_aTc*(u_aTc-y[1])-0.0165*y[1];
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState3(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(4)
    alpha[0] = (k_IPTG*u_IPTG)/(k_IPTG+0.0165)
    alpha[1] = (k_aTc*u_aTc)/(k_aTc+0.0165)
    alpha[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(alpha[1]/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(alpha[0]/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode3(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    
    y_al = SteadyState3(p,ivss) # Calculation of initial guesses for steady state
    
    ssv = odeint(model3,y_al,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]
        
        
        
    
    return(final)

# %% [markdown]
# ### Functions to simulate the 3 models for all parameter draws

# %%
def solveALL (ts, pD, sp, inputs, ivss, pre, model):
    
    AllSol = np.empty((len(ts),len(pD[:,1])*2))
    AllSolTest = np.empty(((round(len(ts)/5)+1),len(pD[:,1])*2))
    for drawInd in range(0,len(pD[:,1])):
        
        p = pD[drawInd,:]
        if model == 'M1':
            temp = solve_coupled_ode1(ts, p, sp, inputs, ivss, pre)
        elif model == 'M2':
            temp = solve_coupled_ode2(ts, p, sp, inputs, ivss, pre)
        elif model == 'M3':
            temp = solve_coupled_ode3(ts, p, sp, inputs, ivss, pre)
        else:
            print('Please, select a correct model as M1, M2 or M3 for the desired one')

        AllSolTest[:,drawInd] = temp[:,2][::5]
        AllSolTest[:,drawInd+(len(pD[:,1]))] = temp[:,3][::5]

    return(AllSolTest)

# %% [markdown]
# ### Example:

# %%
ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
inputs = np.empty(18) # What needs to be optimised    --> example: [1e-7,100,1,1e-7]*4+[1e-7,100]
evnT = [int(i) for i in list(np.linspace(0,(24*60),10))]
t = np.linspace(0,(24*60),(24*60)+1)
pM3 = np.asarray(pd.read_csv("ParametersCSV/draws_ALL_Model3.stan.csv"))

# %%
p = pM3[0:5,:]
test = solveALL(t,p,evnT,[1e-7,100,1,1e-7]*4+[1e-7,100],ivss,pre, 'M3')
plt.figure()
plt.plot(t[::5], test[:,0:5], 'r')
plt.plot(t[::5], test[:,5:10], 'g')
plt.show()

# %% [markdown]
# ### Bhattacharyya distance function:

# %%
def BhattacharyyaDist (mu1, mu2, sd1, sd2):
    E = (sd1+sd2)/2
    Em1 = np.linalg.inv(E)
    dE = abs(np.linalg.det(E))

    t1 = np.matrix.transpose((np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))))
    t2 = np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))
    
    ft = (1/8)*t1*Em1*t2
    st = dE/np.sqrt(abs(np.linalg.det(sd1))*abs(np.linalg.det(sd2)))
    
    bhd = ft+0.5*np.log(st)
    
    return(float(bhd))

# %% [markdown]
# ### Definition of the utility function:

# %%
def utility2 (IPTG1, IPTG2,
             aTc1, aTc2):
    
    # Definition of inputs for the ODEs
        
    inputs = [round(IPTG1,2)+1e-7, int(aTc1)+1e-7, round(IPTG2,2)+1e-7, int(aTc2)+1e-7]
    
    # Initial values for steady state and inputs
    ivss = [1,1e-7,1363.193,28.510]
    pre = [1,1e-7]
    # Event switches and inputs
    sp = [int(i) for i in list(np.linspace(0,(24*60),3))]
    t =  np.linspace(0,(24*60),(24*60)+1)
    
    # load parameter draws for the two models
    pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
    pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))
    
    # Simulation of the system for the two models and extract of results
    solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
    solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')
    
    RFP_M1 = solM1[:,0:len(pM1[:,1])]
    GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]
    
    RFP_M2 = solM2[:,0:len(pM2[:,1])]
    GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]
    
    # Gaussian Process Regression and Reduction
    
    # Means and standard deviations for each time point for each species and for each model
    tgp = np.linspace(0,(24*60),round(24*60/5)+1)
    
#     muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
#     sdR3 = RFP_M2.std(axis = 1)
    muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
    sdG3 = GFP_M2.std(axis = 1)
#     muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
#     sdR2 = RFP_M1.std(axis = 1)
    muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
    sdG2 = GFP_M1.std(axis = 1)

    # Gaussian Process regression
#     gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
#     gR3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
#     gR3.predict(tgp)
    
    gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
    gG3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG3.predict(tgp)
    
#     gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
#     gR2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
#     gR2.predict(tgp)
    
    gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
    gG2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG2.predict(tgp)
    
    # Time points reduction

#     muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
#     tref = list(tgp[::10])

#     g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
#     g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
#     g2R3.predict(tref)

    
#     muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
#     tref = list(tgp[::10])

#     g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
#     g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
#     g2R2.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
    tref = list(tgp[::10])

    g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G3.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
    tref = list(tgp[::10])

    
    g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G2.predict(tref)

    
    # Bhattacharyya distance:
#     bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
    bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
    
    # Utility function value
    u_B = (bdG)

    return(u_B)

# %% [markdown]
# ### Bayesian Optimisation:

# %%
# Bounded region of parameter space

pbounds = {'IPTG1': (0, 1), 'IPTG2': (0, 1),
           'aTc1': (0, 100), 'aTc2': (0, 100)}

# %% [markdown]
# Setting Bayesian Optimisation with our utility function

# %%
optimizer3 = BayesianOptimization(
    f=utility2,
    pbounds=pbounds,
    verbose=2, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1324,
)

# %% [markdown]
# Begin optimisation rutine

# %%
optimizer3.maximize(
    init_points=0,
    n_iter=196,
    alpha=1e-2,
    n_restarts_optimizer=3, 
#     acq="ei", 
#     xi=1e-4
)
# Out:
# |   iter    |  target   |   IPTG1   |   IPTG2   |   aTc1    |   aTc2    |
# -------------------------------------------------------------------------
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
# |  809      |  4.225e+0 |  0.691    |  0.7257   |  19.36    |  24.11    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
# |  810      |  1.018e+0 |  0.3021   |  0.4651   |  20.1     |  23.95    |
# |  811      |  2.696e+0 |  0.5781   |  0.6644   |  20.04    |  24.12    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
# |  812      |  1.76e+03 |  0.06898  |  0.4604   |  21.0     |  23.33    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
# |  813      |  1.934e+0 |  0.4519   |  0.4793   |  19.5     |  24.43    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
# |  814      |  1.244e+0 |  0.3339   |  0.5286   |  19.0     |  24.21    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 12
# |  815      |  2.506e+0 |  0.4742   |  0.4455   |  18.95    |  23.99    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
# |  816      |  1.916e+0 |  0.3268   |  0.2368   |  18.55    |  23.43    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
# |  817      |  2.756e+0 |  0.5642   |  0.5008   |  19.94    |  23.59    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
# |  818      |  1.413e+0 |  0.5182   |  0.5685   |  18.97    |  24.01    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
# |  819      |  3.373e+0 |  0.3772   |  0.3728   |  19.59    |  23.74    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 14
# |  820      |  3.045e+0 |  0.5529   |  0.5038   |  20.18    |  24.38    |
# |  821      |  1.637e+0 |  0.6237   |  0.5935   |  19.31    |  24.05    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 4
# |  822      |  2.35e+05 |  0.8426   |  0.9171   |  19.58    |  23.27    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
# |  823      |  6.994e+0 |  0.6254   |  0.4803   |  20.09    |  24.59    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 13
# |  824      |  2.104e+0 |  0.696    |  0.6205   |  19.96    |  23.43    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
# |  825      |  5.501e+0 |  0.9144   |  0.7924   |  19.27    |  24.16    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
# |  826      |  1.941e+0 |  0.726    |  0.7566   |  19.33    |  24.35    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
# |  827      |  567.4    |  0.8779   |  0.02888  |  22.39    |  69.03    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 10
# |  828      |  1.057e+0 |  0.4571   |  0.3675   |  19.35    |  23.62    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
# |  829      |  1.669e+0 |  0.3421   |  0.3374   |  19.27    |  24.39    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
# |  830      |  1.228e+0 |  0.4559   |  0.5175   |  19.08    |  24.62    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 10
# |  831      |  1.023e+0 |  0.729    |  0.6052   |  19.21    |  24.04    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
# |  832      |  1.082e+0 |  0.5706   |  0.5349   |  18.38    |  24.89    |
#  Warning: optimization failed at run 3
# |  833      |  1.49e+06 |  0.3464   |  0.319    |  18.8     |  23.95    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
# |  834      |  1.652e+0 |  0.4372   |  0.4807   |  19.99    |  24.21    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
# |  835      |  1.44e+06 |  0.4438   |  0.4936   |  20.6     |  24.26    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
# |  836      |  5.261e+0 |  0.4416   |  0.5468   |  19.08    |  24.48    |
#  Warning: optimization failed at run 8
# |  837      |  5.18e+04 |  0.8479   |  0.7223   |  19.3     |  24.15    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 13
# |  838      |  6.142e+0 |  0.6424   |  0.69     |  19.59    |  23.32    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 14
# |  839      |  6.07e+05 |  0.796    |  0.7654   |  20.13    |  23.58    |
#  Warning: optimization failed at run 7
# |  840      |  2.916e+0 |  0.4627   |  0.2947   |  18.96    |  23.85    |
# |  841      |  1.209e+0 |  0.7936   |  0.711    |  19.33    |  23.47    |
#  Warning: optimization failed at run 10
# |  842      |  2.265e+0 |  0.6908   |  0.6649   |  19.16    |  24.8     |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 12
# |  843      |  6.043e+0 |  0.4147   |  0.3473   |  18.86    |  23.67    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 8
# |  844      |  8.051e+0 |  0.3941   |  0.3443   |  20.45    |  24.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  845      |  1.265e+0 |  0.3688   |  0.4073   |  19.03    |  24.63    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
# |  846      |  7.44e+05 |  0.7953   |  0.7871   |  20.14    |  23.76    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 10
# |  847      |  2.517e+0 |  0.704    |  0.6782   |  19.22    |  24.3     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 2
# |  848      |  2.389e+0 |  0.3497   |  0.3553   |  19.47    |  23.85    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
# |  849      |  2.292e+0 |  0.7266   |  0.6856   |  19.19    |  23.98    |
#  Warning: optimization failed at run 11
# |  850      |  2.162e+0 |  0.7475   |  0.7415   |  19.45    |  24.12    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
# |  851      |  2.223e+0 |  0.4352   |  0.458    |  18.96    |  23.68    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 6
# |  852      |  3.447e+0 |  0.5795   |  0.573    |  19.93    |  23.55    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 8
# |  853      |  2.202e+0 |  0.5309   |  0.5399   |  19.2     |  24.8     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 6
# |  854      |  4.53e+05 |  0.4115   |  0.3408   |  19.56    |  23.79    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
# |  855      |  3.405e+0 |  0.768    |  0.8516   |  19.7     |  23.42    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
# |  856      |  2.313e+0 |  0.3883   |  0.38     |  19.9     |  24.32    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
# |  857      |  1.626e+0 |  0.6187   |  0.5851   |  19.29    |  24.15    |
#  Warning: optimization failed at run 6
# |  858      |  1.47e+05 |  0.7518   |  0.6479   |  19.85    |  23.74    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
# |  859      |  2.143e+0 |  0.4344   |  0.4563   |  20.8     |  24.39    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
# |  860      |  1.494e+0 |  0.5327   |  0.4375   |  20.07    |  23.42    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
# |  861      |  1.945e+0 |  0.5846   |  0.6887   |  19.92    |  23.96    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 1
# |  862      |  1.022e+0 |  0.5241   |  0.4202   |  19.03    |  23.52    |
#  Warning: optimization failed at run 4
# |  863      |  1.959e+0 |  0.5958   |  0.6133   |  19.78    |  24.67    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
# |  864      |  9.029e+0 |  0.4624   |  0.5634   |  20.71    |  24.49    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
# |  865      |  1.781e+0 |  0.5178   |  0.4983   |  18.71    |  24.66    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
# |  866      |  8.905e+0 |  0.7047   |  0.3512   |  18.04    |  24.85    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
# |  867      |  1.865e+0 |  0.4711   |  0.4351   |  19.46    |  24.0     |
#  Warning: optimization failed at run 15
# |  868      |  1.17e+05 |  0.5421   |  0.6651   |  19.97    |  23.46    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 1
# |  869      |  3.175e+0 |  0.5303   |  0.5398   |  19.88    |  23.89    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
# |  870      |  2.759e+0 |  0.4922   |  0.4879   |  20.19    |  24.84    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 5
# |  871      |  1.712e+0 |  0.3489   |  0.3483   |  19.14    |  24.51    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
# |  872      |  1.581e+0 |  0.4852   |  0.4919   |  18.73    |  24.55    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
# |  873      |  1.469e+0 |  0.7551   |  0.6631   |  19.39    |  23.93    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
# |  874      |  1.768e+0 |  0.4925   |  0.525    |  19.45    |  24.38    |
# |  875      |  3.79e+04 |  0.2566   |  0.5781   |  19.93    |  23.31    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
# |  876      |  1.501e+0 |  0.4839   |  0.5322   |  19.14    |  24.82    |
#  Warning: optimization failed at run 8
# |  877      |  1.827e+0 |  0.5081   |  0.581    |  20.09    |  24.85    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
# |  878      |  1.309e+0 |  0.2646   |  0.189    |  0.1599   |  24.82    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
# |  879      |  1.636e+0 |  0.5075   |  0.4728   |  20.7     |  24.39    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
# |  880      |  5.277e+0 |  0.7042   |  0.6627   |  19.79    |  23.68    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 9
# |  881      |  6.296e+0 |  0.3699   |  0.4497   |  18.79    |  24.13    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
# |  882      |  5.383e+0 |  0.7597   |  0.799    |  19.64    |  23.36    |
# |  883      |  2.468e+0 |  0.6968   |  0.6872   |  19.31    |  24.3     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 15
# |  884      |  3.197e+0 |  0.5102   |  0.3434   |  18.73    |  24.65    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 2
# |  885      |  1.098e+0 |  0.5247   |  0.4162   |  20.22    |  24.73    |
# |  886      |  1.777e+0 |  0.601    |  0.568    |  19.27    |  24.73    |
#  Warning: optimization failed at run 14
# |  887      |  1.596e+0 |  0.5141   |  0.5122   |  18.69    |  24.96    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
# |  888      |  3.559e+0 |  0.4085   |  0.4015   |  19.47    |  23.74    |
#  Warning: optimization failed at run 5
# |  889      |  2.57e+05 |  0.8346   |  0.7783   |  19.72    |  23.48    |
# |  890      |  4.499e+0 |  0.2528   |  0.4929   |  19.24    |  25.17    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 14
# |
|
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
# |  966      |  7.607e+0 |  0.4093   |  0.3632   |  18.79    |  24.1     |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 2
# |  967      |  2.7e+06  |  0.6327   |  0.6121   |  19.08    |  24.87    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 1
# |  968      |  1.08e+06 |  0.4398   |  0.5107   |  19.96    |  23.32    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 11
# |  969      |  1.545e+0 |  0.5004   |  0.4593   |  18.93    |  24.0     |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
# |  970      |  2.949e+0 |  0.5384   |  0.5563   |  19.88    |  23.5     |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 4
# |  971      |  9.466e+0 |  0.3305   |  0.3814   |  18.71    |  23.52    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 2
# |  972      |  4.124e+0 |  0.3857   |  0.4977   |  19.06    |  24.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
# |  973      |  6.832e+0 |  0.4514   |  0.3926   |  19.97    |  24.4     |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
# |  974      |  8.292e+0 |  0.3901   |  0.3425   |  19.11    |  23.98    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 10
# |  975      |  3.07e+05 |  0.2736   |  0.3257   |  19.09    |  24.4     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
# |  976      |  1.641e+0 |  0.5377   |  0.5939   |  19.92    |  24.13    |
#  Warning: optimization failed at run 13
# |  977      |  3.689e+0 |  0.6516   |  0.6038   |  19.86    |  23.69    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
# |  978      |  2.044e+0 |  0.5223   |  0.5503   |  19.19    |  24.68    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
# |  979      |  1.261e+0 |  0.3386   |  0.544    |  19.05    |  23.58    |
#  Warning: optimization failed at run 9
# |  980      |  1.206e+0 |  0.4799   |  0.5681   |  19.07    |  23.64    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
# |  981      |  5.251e+0 |  0.3032   |  0.3927   |  19.53    |  23.77    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
# |  982      |  2.406e+0 |  0.3703   |  0.3766   |  20.24    |  24.59    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 13
# |  983      |  1.008e+0 |  0.4704   |  0.6371   |  19.5     |  23.95    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 14
# |  984      |  1.203e+0 |  0.2875   |  0.2671   |  20.29    |  24.54    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
# |  985      |  2.154e+0 |  0.2053   |  0.3476   |  20.72    |  24.67    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
# |  986      |  2.257e+0 |  0.5429   |  0.6295   |  20.08    |  23.63    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
# |  987      |  8.28e+04 |  0.648    |  0.5135   |  20.13    |  24.78    |
#  Warning: optimization failed at run 6
# |  988      |  3.985e+0 |  0.6836   |  0.7505   |  19.42    |  24.22    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
# |  989      |  9.451e+0 |  0.4759   |  0.3842   |  21.24    |  24.34    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
# |  990      |  1.732e+0 |  0.369    |  0.5445   |  20.62    |  24.4     |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
# |  991      |  7.04e+05 |  0.3641   |  0.434    |  19.15    |  23.91    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  992      |  1.614e+0 |  0.3203   |  0.4786   |  18.96    |  24.65    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 13
# |  993      |  1.33e+06 |  0.3963   |  0.4449   |  18.79    |  24.44    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 9
# |  994      |  8.622e+0 |  0.3442   |  0.3879   |  19.58    |  24.01    |
#  Warning: optimization failed at run 5
# |  995      |  4.999e+0 |  0.4978   |  0.3646   |  19.06    |  24.83    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 14
# |  996      |  1.859e+0 |  0.3681   |  0.1951   |  21.12    |  24.37    |
# |  997      |  2.536e+0 |  0.6674   |  0.6129   |  19.04    |  24.03    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 14
# |  998      |  3.03e+05 |  0.4438   |  0.3461   |  18.93    |  24.09    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
# |  999      |  9.037e+0 |  0.4283   |  0.3384   |  18.74    |  23.94    |
#  Warning: optimization failed at run 1
# |  1000     |  1.361e+0 |  0.7772   |  0.6779   |  19.14    |  24.82    |
#  Warning: optimization failed at run 13
# |  1001     |  4.464e+0 |  0.7185   |  0.5173   |  20.58    |  24.21    |
#  Warning: optimization failed at run 9
# |  1002     |  1.536e+0 |  0.4575   |  0.2366   |  18.37    |  23.69    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
# |  1003     |  2.31e+06 |  0.666    |  0.6365   |  19.15    |  24.45    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
# |  1004     |  1.312e+0 |  0.4382   |  0.4954   |  19.98    |  23.9     |
# =========================================================================

# %%
# Save results obtained
with open('config3sGFP3.optim', 'wb') as config_optim_file:
 
    pickle.dump(optimizer3, config_optim_file)

# %%
# Best utility value generated
print(optimizer3.max)
# Out:
# {'target': 6295866.818467173, 'params': {'IPTG1': 0.5877438918902653, 'IPTG2': 0.5797947426202839, 'aTc1': 20.01510361324723, 'aTc2': 23.39225167261566}}

# %% [markdown]
# Plot best utility value so far per iteration:

# %%
v = []
for i, res in enumerate(optimizer3.res):
    v.append(res['target'])
    
vn = []
for i, val in enumerate(v):
    mv = max(v[0:i+1])
    vn.append(mv)
    
plt.figure()
plt.plot(vn)
plt.plot(v)
plt.show()

# %%
df = pd.DataFrame({
    'CFV': v})
df.to_csv('CFV_Iter_2S_GFP.csv')

df = pd.DataFrame({
    'CFV': vn})
df.to_csv('bestCFV_Iter_2S_GFP.csv')

# %% [markdown]
# ### Check results with plot

# %%
inputs = [round(optimizer3.max['params']['IPTG1'], 2)+1e-7, int(optimizer3.max['params']['aTc1'])+1e-7, 
          round(optimizer3.max['params']['IPTG2'], 2)+1e-7, int(optimizer3.max['params']['aTc2'])+1e-7]

ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
sp = [int(i) for i in list(np.linspace(0,(24*60),3))]
t =  np.linspace(0,(24*60),(24*60)+1)

pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))

# Simulation of the system for the two models and extract of results
solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')

RFP_M1 = solM1[:,0:len(pM1[:,1])]
GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]

RFP_M2 = solM2[:,0:len(pM2[:,1])]
GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]

# %%
t = np.linspace(0,(24*60),round(24*60/5)+1)

plt.figure()
lines = plt.plot(t, GFP_M2, 'c')
plt.text((24*60)+1, 800, "Model 2", bbox=dict(facecolor='c'))
plt.title("Average")
lines2 = plt.plot(t, GFP_M1, 'g')
plt.text((24*60)+1, 600, "Model 1", bbox=dict(facecolor='g'))

plt.show()
plt.figure()
plt.plot(t, RFP_M2, 'c')

plt.text((24*60)+1, 500, "Model 2", bbox=dict(facecolor='c'))
plt.text((24*60)+1, 40, "Model 1", bbox=dict(facecolor='r'))
plt.plot(t, RFP_M1, 'r')
plt.show()

# %% [markdown]
# ### Check utility decomposition results

# %%
# Gaussian Process Regression and Reduction

# Means and standard deviations for each time point for each species and for each model
tgp = np.linspace(0,(24*60),(24*60/5)+1)

muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
sdR3 = RFP_M2.std(axis = 1)
muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
sdG3 = GFP_M2.std(axis = 1)
muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
sdR2 = RFP_M1.std(axis = 1)
muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
sdG2 = GFP_M1.std(axis = 1)

# Gaussian Process regression
gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
gR3.findhyperparameters(noruns=15)
gR3.predict(tgp)

gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
gG3.findhyperparameters(noruns=15)
gG3.predict(tgp)

gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
gR2.findhyperparameters(noruns=15)
gR2.predict(tgp)

gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
gG2.findhyperparameters(noruns=15)
gG2.predict(tgp)

# %%
muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R2.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G2.predict(tref)

# %%
bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
u_B = (bdR*bdG)

# %%
print("The BD for RFP is: ", str(bdR))
print("The BD for GFP is: ", str(bdG))
print("The multiplicative BD is: ", str(u_B))
print("The average BD is: ", str((bdR+bdG)/2))
