# %% [markdown]
# # Bayesian Experimental Design for model selection

# %% [markdown]
# Script used to perform a 4 step optimisation with a Matern Kernel with nu=1.5. To change the Kernel, this needs to be done in the source code of the package used since there is no apparent parameter in the functions to modulate it. The acquisition function has been changed to EI, where xi=1e-1 to decrease the smoothness of the kernel
#
#    ............................................................................................................................................................................................................................................

# %% [markdown]
# ### Import Required libraries

# %%
import numpy as np
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import seaborn as sns
from numba import jit
import gaussianprocess as gp
from fitderiv import fitderiv
import genutils as gu
import datetime
from bayes_opt import BayesianOptimization
from bayes_opt.observer import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs
import pickle

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import math

# %% [markdown]
# ### Model 1 Functions (ODEs, Steady State and Event based representation)
# * Lugagne et. al. Model

# %%
@jit
def model1(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    
    if u_IPTG > y[0]:
        dInd_dt[0]=k_in_IPTG*(u_IPTG-y[0])
    else:
        dInd_dt[0]=k_out_IPTG*(u_IPTG-y[0])
    
    if u_aTc > y[2]:
        dInd_dt[1]=k_in_aTc*(u_aTc-y[1])
    else:
        dInd_dt[1]=k_out_aTc*(u_aTc-y[1])
    
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState1(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode1(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState1(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model1,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 2 Functions (ODEs, Steady State and Event based representation)
# * Intermediate Model (Single rate, no degradation)

# %%
@jit
def model2(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0]);
    dInd_dt[1] = k_aTc*(u_aTc-y[1]);
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState2(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode2(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState2(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model2,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 3 Functions (ODEs, Steady State and Event based representation)
# * Lucia's Model

# %%
@jit
def model3(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0])-0.0165*y[0];
    dInd_dt[1] = k_aTc*(u_aTc-y[1])-0.0165*y[1];
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState3(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(4)
    alpha[0] = (k_IPTG*u_IPTG)/(k_IPTG+0.0165)
    alpha[1] = (k_aTc*u_aTc)/(k_aTc+0.0165)
    alpha[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(alpha[1]/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(alpha[0]/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode3(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    
    y_al = SteadyState3(p,ivss) # Calculation of initial guesses for steady state
    
    ssv = odeint(model3,y_al,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]
        
        
        
    
    return(final)

# %% [markdown]
# ### Functions to simulate the 3 models for all parameter draws

# %%
def solveALL (ts, pD, sp, inputs, ivss, pre, model):
    
    AllSol = np.empty((len(ts),len(pD[:,1])*2))
    AllSolTest = np.empty(((round(len(ts)/5)+1),len(pD[:,1])*2))
    for drawInd in range(0,len(pD[:,1])):
        
        p = pD[drawInd,:]
        if model == 'M1':
            temp = solve_coupled_ode1(ts, p, sp, inputs, ivss, pre)
        elif model == 'M2':
            temp = solve_coupled_ode2(ts, p, sp, inputs, ivss, pre)
        elif model == 'M3':
            temp = solve_coupled_ode3(ts, p, sp, inputs, ivss, pre)
        else:
            print('Please, select a correct model as M1, M2 or M3 for the desired one')

        AllSolTest[:,drawInd] = temp[:,2][::5]
        AllSolTest[:,drawInd+(len(pD[:,1]))] = temp[:,3][::5]

    return(AllSolTest)

# %% [markdown]
# ### Example:

# %%
ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
inputs = np.empty(18) # What needs to be optimised    --> example: [1e-7,100,1,1e-7]*4+[1e-7,100]
evnT = [int(i) for i in list(np.linspace(0,(24*60),10))]
t = np.linspace(0,(24*60),(24*60)+1)
pM3 = np.asarray(pd.read_csv("ParametersCSV/draws_ALL_Model3.stan.csv"))

# %%
p = pM3[0:5,:]
test = solveALL(t,p,evnT,[1e-7,100,1,1e-7]*4+[1e-7,100],ivss,pre, 'M3')
plt.figure()
plt.plot(t[::5], test[:,0:5], 'r')
plt.plot(t[::5], test[:,5:10], 'g')
plt.show()

# %% [markdown]
# ### Bhattacharyya distance function:

# %%
def BhattacharyyaDist (mu1, mu2, sd1, sd2):
    E = (sd1+sd2)/2
    Em1 = np.linalg.inv(E)
    dE = abs(np.linalg.det(E))

    t1 = np.matrix.transpose((np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))))
    t2 = np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))
    
    ft = (1/8)*t1*Em1*t2
    st = dE/np.sqrt(abs(np.linalg.det(sd1))*abs(np.linalg.det(sd2)))
    
    bhd = ft+0.5*np.log(st)
    
    return(float(bhd))

# %% [markdown]
# ### Definition of the utility function:

# %%
def utility2 (IPTG1, IPTG2, IPTG3, IPTG4,
             aTc1, aTc2, aTc3, aTc4):
    
    # Definition of inputs for the ODEs
        
    inputs = [round(IPTG1,2)+1e-7, int(aTc1)+1e-7, round(IPTG2,2)+1e-7, int(aTc2)+1e-7,
              round(IPTG3,2)+1e-7, int(aTc3)+1e-7, round(IPTG4,2)+1e-7, int(aTc4)+1e-7]
    
    # Initial values for steady state and inputs
    ivss = [1,1e-7,1363.193,28.510]
    pre = [1,1e-7]
    # Event switches and inputs
    sp = [int(i) for i in list(np.linspace(0,(24*60),5))]
    t =  np.linspace(0,(24*60),(24*60)+1)
    
    # load parameter draws for the two models
    pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
    pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))
    
    # Simulation of the system for the two models and extract of results
    solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
    solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')
    
    RFP_M1 = solM1[:,0:len(pM1[:,1])]
    GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]
    
    RFP_M2 = solM2[:,0:len(pM2[:,1])]
    GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]
    
    # Gaussian Process Regression and Reduction
    
    # Means and standard deviations for each time point for each species and for each model
    tgp = np.linspace(0,(24*60),round(24*60/5)+1)
    
    #muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
    #sdR3 = RFP_M2.std(axis = 1)
    muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
    sdG3 = GFP_M2.std(axis = 1)
    #muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
    #sdR2 = RFP_M1.std(axis = 1)
    muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
    sdG2 = GFP_M1.std(axis = 1)

    # Gaussian Process regression
    #gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
    #gR3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    #gR3.predict(tgp)
    
    gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
    gG3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG3.predict(tgp)
    
    #gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
    #gR2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    #gR2.predict(tgp)
    
    gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
    gG2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG2.predict(tgp)
    
    # Time points reduction

    #muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
    #tref = list(tgp[::10])

    #g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    #g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    #g2R3.predict(tref)

    
    #muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
    #tref = list(tgp[::10])

    #g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    #g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    #g2R2.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
    tref = list(tgp[::10])

    g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G3.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
    tref = list(tgp[::10])

    
    g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G2.predict(tref)

    
    # Bhattacharyya distance:
    #bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
    bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
    
    # Utility function value
    u_B = (bdG)

    return(u_B)

# %% [markdown]
# ### Bayesian Optimisation:

# %%
# Bounded region of parameter space

pbounds = {'IPTG1': (0, 1), 'IPTG2': (0, 1), 'IPTG3': (0, 1), 'IPTG4': (0, 1),
           'aTc1': (0, 100), 'aTc2': (0, 100), 'aTc3': (0, 100), 'aTc4': (0, 100)}

# %% [markdown]
# Setting Bayesian Optimisation with our utility function

# %%
optimizer3 = BayesianOptimization(
    f=utility2,
    pbounds=pbounds,
    verbose=2, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1324,
)

# %% [markdown]
# Begin optimisation rutine

# %%
optimizer3.maximize(
    init_points=0,
    n_iter=1000,
    alpha=1e-2,
    n_restarts_optimizer=3, 
    acq="ei", 
    xi=1e-1
)
# Out:
# |   iter    |  target   |   IPTG1   |   IPTG2   |   IPTG3   |   IPTG4   |   aTc1    |   aTc2    |   aTc3    |   aTc4    |
# -------------------------------------------------------------------------------------------------------------------------
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
# |  1005     |  2.543e+0 |  0.3095   |  0.4119   |  0.9705   |  0.4983   |  42.95    |  38.46    |  34.68    |  5.931    |
# |  1006     |  2.604e+0 |  0.8781   |  0.843    |  0.2035   |  0.7918   |  15.4     |  21.17    |  45.2     |  20.89    |
#  Warning: optimization failed at run 13
# |  1007     |  3.002e+0 |  0.5441   |  0.8158   |  0.2743   |  0.1225   |  23.22    |  26.67    |  91.49    |  19.53    |
#  Warning: optimization failed at run 13
# |  1008     |  139.3    |  0.6063   |  0.06854  |  0.1391   |  0.9932   |  87.87    |  21.68    |  33.22    |  17.32    |
#  Warning: optimization failed at run 10
# |  1009     |  3.089e+0 |  0.4356   |  0.7197   |  0.4405   |  0.4411   |  48.83    |  31.97    |  15.47    |  9.008    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 15
# |  1010     |  1.813e+0 |  0.1938   |  0.8617   |  0.7184   |  0.7567   |  93.3     |  18.71    |  31.12    |  45.41    |
#  Warning: optimization failed at run 1
# |  1011     |  706.1    |  0.225    |  0.4923   |  0.2045   |  0.6082   |  70.15    |  76.24    |  66.73    |  7.685    |
# |  1012     |  1.085e+0 |  0.2748   |  0.7652   |  0.0101   |  0.09306  |  21.15    |  91.74    |  77.52    |  66.64    |
# |  1013     |  1.099e+0 |  0.1964   |  0.9785   |  0.8504   |  0.5963   |  39.43    |  6.451    |  94.34    |  85.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
# |  1014     |  1.75e+03 |  0.5902   |  0.2797   |  0.3831   |  0.6544   |  26.76    |  60.28    |  82.38    |  6.349    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
# |  1015     |  1.114e+0 |  0.1616   |  0.1428   |  0.1097   |  0.2815   |  50.16    |  43.28    |  41.83    |  25.73    |
#  Warning: optimization failed at run 5
# |  1016     |  182.0    |  0.5907   |  0.1415   |  0.05409  |  0.442    |  72.19    |  56.05    |  29.2     |  71.1     |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 11
# |  1017     |  166.0    |  0.0918   |  0.4778   |  0.00859  |  0.8432   |  93.76    |  36.23    |  3.644    |  43.82    |
#  Warning: optimization failed at run 1
# |  1018     |  351.4    |  0.3959   |  0.415    |  0.8352   |  0.06696  |  55.87    |  39.96    |  22.69    |  41.66    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
# |  1019     |  85.81    |  0.4962   |  0.1123   |  0.05143  |  0.6408   |  95.66    |  0.7728   |  18.01    |  60.92    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 6
# |  1020     |  1.147e+0 |  0.8286   |  0.2123   |  0.4326   |  0.3705   |  40.76    |  30.25    |  12.62    |  88.41    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
# |  1021     |  2.545e+0 |  0.2686   |  0.716    |  0.9988   |  0.4386   |  81.61    |  9.306    |  7.111    |  88.22    |
#  Warning: optimization failed at run 1
# |  1022     |  507.4    |  0.1076   |  0.1779   |  0.08431  |  0.6609   |  63.05    |  94.79    |  9.701    |  35.07    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
# |  1023     |  2.325e+0 |  0.8511   |  0.7848   |  0.908    |  0.7161   |  89.92    |  35.9     |  82.04    |  42.08    |
# |  1024     |  357.9    |  0.6168   |  0.01727  |  0.8248   |  0.94     |  49.19    |  17.8     |  59.59    |  8.776    |
#  Warning: optimization failed at run 6
# |  1025     |  277.7    |  0.8069   |  0.06529  |  0.2869   |  0.47     |  22.38    |  22.14    |  23.41    |  39.87    |
# |  1026     |  1.221e+0 |  0.922    |  0.782    |  0.05088  |  0.04863  |  18.85    |  59.82    |  76.56    |  11.81    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
# |  1027     |  3.7e+03  |  0.6356   |  0.3739   |  0.3628   |  0.6692   |  25.18    |  16.25    |  70.22    |  0.9654   |
#  Warning: optimization failed at run 5
# |  1028     |  403.6    |  0.7578   |  0.8461   |  0.09704  |  0.4361   |  94.48    |  37.31    |  78.57    |  27.19    |
# |  1029     |  159.1    |  0.9198   |  0.1061   |  0.03838  |  0.2107   |  15.3     |  67.49    |  8.821    |  5.66     |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
# |  1030     |  1.997e+0 |  0.8971   |  0.1463   |  0.4373   |  0.7219   |  99.23    |  0.7117   |  19.28    |  41.95    |
# |  1031     |  2.662e+0 |  0.5335   |  0.4322   |  0.9676   |  0.2278   |  11.07    |  19.56    |  53.51    |  48.64    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
# |  1032     |  347.1    |  0.6784   |  0.4163   |  0.0449   |  0.67     |  49.17    |  44.47    |  67.06    |  88.07    |
#  Warning: optimization failed at run 15
# |  1033     |  124.3    |  0.3812   |  0.02197  |  0.2371   |  0.3125   |  50.21    |  2.895    |  60.54    |  64.74    |
# |  1034     |  221.0    |  0.4345   |  0.1585   |  0.9576   |  0.9498   |  77.32    |  39.92    |  52.23    |  32.2     |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  1035     |  92.8     |  0.2911   |  0.2902   |  0.2392   |  0.5899   |  94.29    |  46.87    |  78.94    |  66.05    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 5
# |  1036     |  1.347e+0 |  0.7529   |  0.7062   |  0.5444   |  0.2511   |  86.82    |  15.01    |  84.93    |  70.45    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 4
# |  1037     |  225.0    |  0.6986   |  0.1761   |  0.8665   |  0.3471   |  46.16    |  17.27    |  88.27    |  70.57    |
# |  1038     |  197.3    |  0.0166   |  0.8936   |  0.02919  |  0.4793   |  72.02    |  1.437    |  46.37    |  69.99    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
# |  1039     |  1.553e+0 |  0.3432   |  0.5812   |  0.7763   |  0.2828   |  84.11    |  11.67    |  49.42    |  47.23    |
#  Warning: optimization failed at run 15
# |  1040     |  683.2    |  0.002282 |  0.6536   |  0.5942   |  0.3398   |  31.96    |  29.96    |  67.8     |  29.3     |
#  Warning: optimization failed at run 14
# |  1041     |  1.394e+0 |  0.03736  |  0.7564   |  0.8787   |  0.9549   |  86.97    |  11.54    |  86.21    |  14.35    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
# |  1042     |  2.328e+0 |  0.8467   |  0.8636   |  0.3281   |  0.236    |  50.24    |  33.33    |  42.28    |  51.91    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 6
# |  1043     |  9.02e+03 |  0.5599   |  0.7938   |  0.3009   |  0.1681   |  44.14    |  14.5     |  35.1     |  60.8     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
# |  1044     |  875.8    |  0.6384   |  0.3388   |  0.1046   |  0.09055  |  38.14    |  19.0     |  3.167    |  95.44    |
# |  1045     |  436.5    |  0.3298   |  0.6487   |  0.9446   |  0.5496   |  11.33    |  0.3047   |  56.87    |  86.63    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
# |  1046     |  4.981e+0 |  0.2076   |  0.3789   |  0.4263   |  0.4951   |  79.64    |  72.26    |  7.087    |  3.348    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 12
# |  1047     |  5.181e+0 |  0.7766   |  0.8479   |  0.6753   |  0.5745   |  39.87    |  88.65    |  88.45    |  70.92    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
# |  1048     |  2.776e+0 |  0.522    |  0.4619   |  0.584    |  0.3448   |  51.64    |  4.654    |  73.22    |  82.06    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  1049     |  1.227e+0 |  0.03761  |  0.1262   |  0.2809   |  0.2917   |  38.56    |  99.94    |  64.33    |  46.09    |
#  Warning: optimization failed at run 3
# |  1050     |  1.14e+04 |  0.1873   |  0.3983   |  0.8851   |  0.67     |  14.39    |  29.16    |  26.84    |  81.17    |
#  Warning: optimization failed at run 2
# |  1051     |  175.7    |  0.3034   |  0.8611   |  0.267    |  0.9823   |  73.31    |  69.19    |  47.94    |  41.58    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
# |  1052     |  3.164e+0 |  0.02208  |  0.612    |  0.7707   |  0.5901   |  79.71    |  44.13    |  14.57    |  32.78    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
# |  1053     |  114.9    |  0.2319   |  0.3312   |  0.3144   |  0.9253   |  61.92    |  44.32    |  44.49    |  85.19    |
#  Warning: optimization failed at run 6
# |  1054     |  2.158e+0 |  0.8341   |  0.3718   |  0.3902   |  0.4654   |  23.58    |  36.73    |  81.36    |  69.85    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
# |  1055     |  872.5    |  0.1783   |  0.4135   |  0.7746   |  0.6335   |  43.4     |  46.69    |  56.69    |  96.62    |
#  Warning: optimization failed at run 15
# |  1056     |  283.9    |  0.6267   |  0.6163   |  0.4808   |  0.1377   |  96.11    |  33.34    |  49.83    |  86.76    |
#  Warning: optimization failed at run 4
# |  1057     |  1.268e+0 |  0.462    |  0.9848   |  0.4532   |  0.2573   |  27.34    |  89.0     |  32.37    |  19.33    |
#  Warning: optimization failed at run 4
# |  1058     |  356.0    |  0.3102   |  0.8373   |  0.5623   |  0.5156   |  78.11    |  63.75    |  0.28     |  70.01    |
#  Warning: optimization failed at run 6
# |  1059     |  79.33    |  0.3185   |  0.8719   |  0.2697   |  0.09746  |  87.24    |  57.61    |  85.22    |  46.87    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
# |  1060     |  520.0    |  0.7456   |  0.3701   |  0.4584   |  0.1974   |  40.65    |  40.76    |  92.95    |  95.43    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
# |  1061     |  1.308e+0 |  0.2571   |  0.2854   |  0.4501   |  0.6733   |  56.77    |  68.66    |  33.63    |  28.83    |
#  Warning: optimization failed at run 5
# |  1062     |  1.414e+0 |  0.6016   |  0.9213   |  0.5499   |  0.3923   |  83.77    |  1.942    |  61.8     |  70.65    |
# |  1063     |  1.301e+0 |  0.1526   |  0.7808   |  0.4599   |  0.4899   |  76.76    |  21.78    |  42.19    |  51.68    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
# |  1064     |  291.1    |  0.01605  |  0.8101   |  0.02166  |  0.8126   |  48.08    |  25.36    |  45.63    |  69.44    |
#  Warning: optimization failed at run 3
# |  1065     |  131.4    |  0.04729  |  0.08432  |  0.03736  |  0.2182   |  0.0591   |  80.57    |  20.95    |  68.59    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
# |  1066     |  152.0    |  0.7069   |  0.1851   |  0.1627   |  0.8403   |  75.15    |  98.03    |  97.68    |  0.2158   |
#  Warning: optimization failed at run 9
# |  1067     |  3.249e+0 |  0.2272   |  0.5819   |  0.7083   |  0.5655   |  32.09    |  92.1     |  70.14    |  11.11    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 1
# |  1068     |  319.9    |  0.04656  |  0.8559   |  0.3752   |  0.4842   |  43.59    |  55.99    |  92.14    |  60.73    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 7
# |  1069     |  803.7    |  0.7808   |  0.5211   |  0.7456   |  0.9136   |  68.1     |  33.81    |  46.39    |  56.01    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 8
# |  1070     |  811.2    |  0.6728   |  0.5671   |  0.09084  |  0.6331   |  21.02    |  15.37    |  80.27    |  93.44    |
#  Warning: optimization failed at run 9
# |  1071     |  6.418e+0 |  0.4504   |  0.8232   |  0.5597   |  0.9804   |  32.15    |  37.88    |  32.85    |  99.8     |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
# |  1072     |  1.125e+0 |  0.1382   |  0.02958  |  0.06118  |  0.2997   |  43.33    |  88.9     |  58.08    |  66.31    |
# |  1073     |  251.0    |  0.04612  |  0.5081   |  0.5388   |  0.3164   |  25.7     |  90.18    |  56.77    |  47.67    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 5
# |  1074     |  709.2    |  0.6202   |  0.4863   |  0.8309   |  0.06793  |  48.47    |  79.86    |  7.114    |  65.72    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 11
# |  1075     |  319.3    |  0.2557   |  0.3024   |  0.4048   |  0.4514   |  94.11    |  89.03    |  59.8     |  42.68    |
#  Warning: optimization failed at run 7
# |  1076     |  3.844e+0 |  0.9086   |  0.8539   |  0.623    |  0.106    |  37.8     |  10.94    |  29.61    |  92.23    |
#  Warning: optimization failed at run 6
# |  1077     |  614.9    |  0.5624   |  0.5475   |  0.07755  |  0.3899   |  24.61    |  39.57    |  50.26    |  44.99    |
# |  1078     |  306.6    |  0.9037   |  0.4297   |  0.0584   |  0.6742   |  72.92    |  87.78    |  1.085    |  70.88    |
#  Warning: optimization failed at run 11
# |  1079     |  296.6    |  0.7848   |  0.04315  |  0.6219   |  0.743    |  86.22    |  10.59    |  73.21    |  14.38    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
# |  1080     |  2.153e+0 |  0.1827   |  0.1092   |  0.7478   |  0.5863   |  47.19    |  70.99    |  10.41    |  38.41    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
# |  1081     |  938.9    |  0.02143  |  0.6118   |  0.8064   |  0.7333   |  95.0     |  75.21    |  52.59    |  33.97    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
# |  1082     |  6.007e+0 |  0.3024   |  0.4278   |  0.4724   |  0.5248   |  63.96    |  29.37    |  26.81    |  1.873    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 15
# |  1083     |  1.009e+0 |  0.1069   |  0.3446   |  0.9573   |  0.8263   |  17.67    |  51.17    |  81.6     |  55.4     |
#  Warning: optimization failed at run 12
# |  1084     |  3.184e+0 |  0.1564   |  0.162    |  0.7523   |  0.5159   |  27.72    |  26.77    |  22.38    |  82.19    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
# |  1085     |  7.61e+03 |  0.7763   |  0.7229   |  0.5201   |  0.2576   |  50.88    |  63.29    |  4.574    |  63.0     |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
# |  1086     |  308.7    |  0.7117   |  0.7213   |  0.8885   |  0.9996   |  9.826    |  88.96    |  72.53    |  57.56    |
#  Warning: optimization failed at run 7
# |  1087     |  1.283e+0 |  0.2795   |  0.5198   |  0.7075   |  0.38     |  24.07    |  65.99    |  80.88    |  92.85    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 3
# |  1088     |  405.7    |  0.4179   |  0.2819   |  0.7691   |  0.2357   |  26.48    |  46.77    |  84.7     |  56.85    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
# |  1089     |  131.1    |  0.5841   |  0.2117   |  0.781    |  0.8349   |  3.27     |  68.44    |  87.37    |  83.86    |
#  Warning: optimization failed at run 15
# |  1090     |  330.3    |  0.8481   |  0.9724   |  0.317    |  0.007149 |  30.69    |  83.91    |  73.13    |  76.7     |
#  Warning: optimization failed at run 12
# |  1091     |  588.4    |  0.219    |  0.8022   |  0.7792   |  0.1393   |  46.32    |  43.38    |  45.8     |  29.17    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
# |  1092     |  174.4    |  0.9755   |  0.333    |  0.08362  |  0.3675   |  75.71    |  47.15    |  77.55    |  34.11    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
# |  1093     |  355.2    |  0.07416  |  0.1009   |  0.3821   |  0.7838   |  93.35    |  27.94    |  44.32    |  27.16    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 10
# |  1094     |  902.0    |  0.2555   |  0.567    |  0.9225   |  0.6925   |  5.145    |  44.47    |  90.66    |  6.555    |
#  Warning: optimization failed at run 6
# |  1095     |  178.9    |  0.907    |  0.01564  |  0.4799   |  0.9694   |  81.21    |  44.89    |  74.14    |  95.35    |
# |  1096     |  2.771e+0 |  0.5344   |  0.9129   |  0.7765   |  0.7266   |  25.32    |  15.98    |  88.74    |  95.74    |
# |  1097     |  841.6    |  0.6115   |  0.7715   |  0.6075   |  0.9052   |  88.76    |  41.81    |  52.57    |  40.57    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
# |  1098     |  341.6    |  0.9435   |  0.9943   |  0.39     |  0.5114   |  11.33    |  94.09    |  39.72    |  99.29    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
# |  1099     |  2.669e+0 |  0.8249   |  0.7264   |  0.9097   |  0.9703   |  76.06    |  64.72    |  35.95    |  41.18    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
# |  1100     |  2.34e+03 |  0.3554   |  0.4341   |  0.8152   |  0.8971   |  66.88    |  36.11    |  0.9559   |  13.6     |
# |  1101     |  780.2    |  0.8936   |  0.715    |  0.3186   |  0.6597   |  86.58    |  35.36    |  34.51    |  88.85    |
# |  1102     |  474.7    |  0.4364   |  0.1214   |  0.5928   |  0.1354   |  16.27    |  19.72    |  89.64    |  45.21    |
#  Warning: optimization failed at run 4
# |  1103     |  645.1    |  0.4637   |  0.972    |  0.4202   |  0.8318   |  11.43    |  86.51    |  16.62    |  70.63    |
# |  1104     |  2.572e+0 |  0.936    |  0.1028   |  0.7157   |  0.5997   |  67.36    |  4.338    |  10.33    |  81.68    |
# |  1105     |  192.6    |  0.7627   |  0.1337   |  0.1618   |  0.2262   |  14.42    |  41.04    |  96.89    |  91.68    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
# |  1106     |  7.601e+0 |  0.08784  |  0.3361   |  0.734    |  0.8688   |  48.43    |  2.032    |  15.57    |  65.31    |
#  Warning: optimization failed at run 11
# |  1107     |  1.016e+0 |  0.01775  |  0.9661   |  0.554    |  0.1386   |  50.38    |  6.775    |  89.04    |  25.93    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
# |  1108     |  245.8    |  0.2343   |  0.3942   |  0.3162   |  0.9793   |  78.34    |  44.18    |  37.96    |  99.07    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
# |  1109     |  271.8    |  0.5151   |  0.8722   |  0.4436   |  0.2145   |  94.38    |  88.37    |  20.77    |  66.35    |
#  Warning: optimization failed at run 15
# |  1110     |  129.7    |  0.5615   |  0.2019   |  0.2922   |  0.5864   |  93.72    |  79.04    |  63.5     |  66.18    |
#  Warning: optimization failed at run 1
# |  1111     |  1.241e+0 |  0.4077   |  0.9763   |  0.2444   |  0.1411   |  46.89    |  18.25    |  91.12    |  75.28    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 11
# |  1112     |  215.3    |  0.6885   |  0.7004   |  0.8841   |  0.2264   |  65.78    |  85.13    |  70.82    |  95.42    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
# |  1113     |  802.0    |  0.2326   |  0.6592   |  0.9493   |  0.5625   |  46.04    |  23.24    |  68.33    |  48.82    |
#  Warning: optimization failed at run 4
# |  1114     |  1.575e+0 |  0.1312   |  0.6086   |  0.1554   |  0.2472   |  89.2     |  6.504    |  44.52    |  18.36    |
#  Warning: optimization failed at run 9
# |  1115     |  3.957e+0 |  0.4889   |  0.4779   |  0.8832   |  0.4753   |  62.22    |  15.12    |  77.12    |  22.59    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 9
# |  1116     |  174.6    |  0.7491   |  0.1452   |  0.01686  |  0.7173   |  65.21    |  90.62    |  67.39    |  39.79    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
# |  1117     |  416.7    |  0.7959   |  0.5853   |  0.412    |  0.244    |  26.59    |  6.887    |  3.285    |  98.7     |
#  Warning: optimization failed at run 12
# |  1118     |  1.123e+0 |  0.6476   |  0.8364   |  0.1552   |  0.2402   |  70.77    |  15.53    |  16.01    |  39.8     |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  1119     |  687.5    |  0.7969   |  0.9777   |  0.175    |  0.4818   |  11.1     |  94.61    |  16.74    |  2.485    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
# |  1120     |  852.0    |  0.9506   |  0.8865   |  0.7121   |  0.1168   |  25.36    |  9.48     |  65.78    |  22.54    |
#  Warning: optimization failed at run 3
# |  1121     |  1.058e+0 |  0.2341   |  0.8591   |  0.7506   |  0.1378   |  9.148    |  24.29    |  57.25    |  34.21    |
#  Warning: optimization failed at run 13
# |  1122     |  856.1    |  0.7343   |  0.8395   |  0.7016   |  0.04502  |  13.26    |  40.47    |  83.98    |  42.99    |
# |  1123     |  1.09e+03 |  0.5836   |  0.3474   |  0.5455   |  0.8462   |  15.61    |  66.81    |  32.36    |  96.13    |
# |  1124     |  1.796e+0 |  0.9527   |  0.8038   |  0.7539   |  0.552    |  18.45    |  16.06    |  70.4     |  1.993    |
# |  1125     |  210.3    |  0.05202  |  0.844    |  0.4398   |  0.1345   |  94.74    |  91.48    |  44.66    |  86.23    |
#  Warning: optimization failed at run 10
# |  1126     |  699.2    |  0.4415   |  0.237    |  0.6687   |  0.9121   |  77.55    |  11.83    |  41.73    |  45.23    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
# |  1127     |  468.7    |  0.8999   |  0.1632   |  0.943    |  0.7592   |  92.82    |  64.32    |  16.02    |  89.31    |
#  Warning: optimization failed at run 7
# |  1128     |  3.523e+0 |  0.8446   |  0.9269   |  0.7896   |  0.473    |  68.37    |  47.17    |  19.17    |  18.38    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
# |  1129     |  1.744e+0 |  0.1436   |  0.3225   |  0.7809   |  0.00401  |  54.11    |  1.668    |  34.68    |  92.69    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
# |  1130     |  894.2    |  0.6909   |  0.8394   |  0.595    |  0.4703   |  74.47    |  73.23    |  67.37    |  78.12    |
# |  1131     |  4.178e+0 |  0.9637   |  0.5489   |  0.9498   |  0.9621   |  34.54    |  53.81    |  39.68    |  18.39    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
# |  1132     |  160.0    |  0.7699   |  0.0839   |  0.0563   |  0.4087   |  82.44    |  3.129    |  96.26    |  72.76    |
# |  1133     |  82.96    |  0.6919   |  0.01269  |  0.9672   |  0.2519   |  0.5973   |  44.63    |  66.55    |  2.251    |
#  Warning: optimization failed at run 7
# |  1134     |  218.4    |  0.04035  |  0.4898   |  0.7908   |  0.03084  |  86.84    |  46.34    |  81.2     |  7.76     |
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
# |  1135     |  223.5    |  0.9609   |  0.8557   |  0.6798   |  0.1293   |  87.41    |  46.98    |  57.79    |  59.52    |
#  Warning: optimization failed at run 12
# |  1136     |  292.3    |  0.2416   |  0.1712   |  0.7347   |  0.7243   |  76.69    |  49.48    |  86.58    |  30.08    |
# |  1137     |  295.9    |  0.4954   |  0.8318   |  0.1105   |  0.05076  |  4.803    |  28.89    |  79.99    |  90.23    |
# |  1138     |  164.6    |  0.8956   |  0.0666   |  0.199    |  0.8585   |  41.53    |  32.61    |  93.67    |  24.73    |
#  Warning: optimization failed at run 2
# |  1139     |  221.5    |  0.7456   |  0.1897   |  0.1056   |  0.4756   |  60.07    |  37.25    |  9.476    |  78.61    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
# |  1140     |  2.265e+0 |  0.4348   |  0.5946   |  0.2384   |  0.4925   |  58.06    |  76.93    |  6.711    |  64.08    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 11
# |  1141     |  347.6    |  0.305    |  0.7863   |  0.7848   |  0.07912  |  7.199    |  44.63    |  50.66    |  64.53    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  1142     |  565.7    |  0.3105   |  0.181    |  0.1342   |  0.1958   |  66.55    |  62.47    |  52.26    |  34.54    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
# |  1143     |  431.1    |  0.7791   |  0.6076   |  0.3932   |  0.04685  |  32.11    |  74.94    |  97.42    |  42.03    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
# |  1144     |  481.8    |  0.01556  |  0.3026   |  0.0463   |  0.3014   |  79.53    |  20.48    |  68.83    |  93.28    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 11
# |  1145     |  303.2    |  0.5043   |  0.03537  |  0.0785   |  0.1665   |  54.89    |  20.56    |  5.94     |  16.67    |
# |  1146     |  1.108e+0 |  0.1045   |  0.6597   |  0.9956   |  0.137    |  29.75    |  26.92    |  56.42    |  25.95    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 13
# |  1147     |  242.2    |  0.0613   |  0.4097   |  0.2661   |  0.6726   |  53.47    |  81.57    |  36.28    |  52.96    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 12
# |  1148     |  620.3    |  0.02461  |  0.9698   |  0.5459   |  0.6157   |  93.88    |  96.28    |  72.88    |  0.6731   |
# |  1149     |  169.6    |  0.8715   |  0.02643  |  0.9911   |  0.2233   |  35.65    |  55.75    |  80.75    |  88.61    |
#  Warning: optimization failed at run 14
# |  1150     |  665.6    |  0.2649   |  0.5295   |  0.6691   |  0.1736   |  75.49    |  49.89    |  8.177    |  94.05    |
# |  1151     |  155.4    |  0.2546   |  0.9504   |  0.03658  |  0.8597   |  60.64    |  64.02    |  89.84    |  72.29    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
# |  1152     |  502.8    |  0.401    |  0.9377   |  0.1335   |  0.07136  |  77.73    |  17.14    |  70.22    |  69.01    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
# |  1153     |  2.354e+0 |  0.7182   |  0.4463   |  0.6156   |  0.4957   |  88.36    |  45.57    |  58.33    |  4.28     |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
# |  1154     |  658.9    |  0.2527   |  0.2456   |  0.2737   |  0.5823   |  54.69    |  57.47    |  17.85    |  29.76    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 2
# |  1155     |  2.276e+0 |  0.8379   |  0.87     |  0.6711   |  0.3734   |  66.15    |  9.49     |  89.15    |  93.86    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
# |  1156     |  440.7    |  0.07428  |  0.1441   |  0.08068  |  0.8888   |  96.57    |  92.01    |  6.934    |  77.76    |
#  Warning: optimization failed at run 5
# |  1157     |  546.6    |  0.9677   |  0.3513   |  0.5743   |  0.1753   |  28.09    |  60.88    |  31.51    |  51.29    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
# |  1158     |  151.8    |  0.2088   |  0.6526   |  0.8275   |  0.01109  |  69.4     |  77.32    |  32.91    |  2.62     |
# |  1159     |  269.5    |  0.01752  |  0.4133   |  0.9385   |  0.2637   |  28.98    |  27.05    |  51.78    |  40.83    |
# |  1160     |  61.37    |  0.65     |  0.1877   |  0.09637  |  0.6228   |  2.14     |  84.46    |  60.24    |  40.24    |
#  Warning: optimization failed at run 13
# |  1161     |  70.7     |  0.6198   |  0.3079   |  0.07886  |  0.6612   |  6.873    |  0.3885   |  98.6     |  72.48    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
# |  1162     |  600.0    |  0.1154   |  0.1719   |  0.3177   |  0.5951   |  28.16    |  19.89    |  93.05    |  63.48    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
# |  1163     |  1.577e+0 |  0.4976   |  0.581    |  0.6218   |  0.9342   |  61.92    |  76.96    |  46.79    |  77.05    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
# |  1164     |  756.9    |  0.3827   |  0.7245   |  0.5292   |  0.6932   |  59.27    |  62.87    |  59.4     |  75.54    |
#  Warning: optimization failed at run 2
# |  1165     |  1.942e+0 |  0.9889   |  0.4122   |  0.7126   |  0.1989   |  12.11    |  44.3     |  13.68    |  26.84    |
#  Warning: optimization failed at run 13
# |  1166     |  251.9    |  0.3089   |  0.5984   |  0.8493   |  0.4288   |  72.78    |  60.75    |  67.78    |  32.17    |
# |  1167     |  587.4    |  0.2218   |  0.4204   |  0.8126   |  0.6635   |  76.92    |  87.28    |  18.39    |  17.93    |
# |  1168     |  225.5    |  0.6623   |  0.02333  |  0.6421   |  0.2355   |  99.72    |  87.23    |  44.82    |  13.9     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 1
# |  1169     |  1.995e+0 |  0.9694   |  0.5542   |  0.1524   |  0.3587   |  53.09    |  4.542    |  35.19    |  68.16    |
# |  1170     |  277.4    |  0.8721   |  0.162    |  0.0893   |  0.8442   |  28.84    |  69.1     |  84.65    |  15.99    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  1171     |  544.7    |  0.1043   |  0.1268   |  0.4531   |  0.7582   |  92.7     |  26.94    |  45.95    |  11.86    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 10
# |  1172     |  133.6    |  0.4633   |  0.2104   |  0.8128   |  0.2155   |  77.01    |  42.29    |  49.59    |  22.32    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
# |  1173     |  767.7    |  0.8689   |  0.8232   |  0.4413   |  0.6909   |  77.73    |  74.04    |  55.96    |  39.89    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
# |  1174     |  1.511e+0 |  0.5554   |  0.4397   |  0.6817   |  0.2998   |  14.21    |  43.24    |  92.2     |  48.16    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
# |  1175     |  1.133e+0 |  0.1604   |  0.5901   |  0.581    |  0.8196   |  54.85    |  39.99    |  84.85    |  31.54    |
# |  1176     |  1.151e+0 |  0.9425   |  0.03098  |  0.7002   |  0.3915   |  42.07    |  1.63     |  42.7     |  17.82    |
#  Warning: optimization failed at run 11
# |  1177     |  165.5    |  0.09811  |  0.6316   |  0.02931  |  0.3386   |  1.873    |  51.7     |  13.38    |  54.62    |
#  Warning: optimization failed at run 10
# |  1178     |  228.3    |  0.8205   |  0.02338  |  0.09714  |  0.7094   |  86.91    |  4.129    |  7.868    |  51.22    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
# |  1179     |  1.288e+0 |  0.8087   |  0.882    |  0.4035   |  0.5397   |  60.51    |  45.03    |  31.14    |  87.53    |
# |  1180     |  29.57    |  0.6658   |  0.1416   |  0.6817   |  0.1161   |  2.04     |  86.09    |  85.92    |  83.51    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 3
# |  1181     |  1.743e+0 |  0.3978   |  0.2615   |  0.5911   |  0.6461   |  48.95    |  71.87    |  21.73    |  43.96    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
# |  1182     |  1.684e+0 |  0.7512   |  0.7098   |  0.5762   |  0.9062   |  71.56    |  78.85    |  46.14    |  34.68    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  1183     |  638.8    |  0.5479   |  0.8897   |  0.2778   |  0.5285   |  3.343    |  20.9     |  77.64    |  8.126    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
# |  1184     |  1.22e+03 |  0.6873   |  0.5269   |  0.6624   |  0.6502   |  63.19    |  54.67    |  70.24    |  79.46    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  1185     |  7.094e+0 |  0.6039   |  0.9433   |  0.3446   |  0.5665   |  51.43    |  23.32    |  26.69    |  29.26    |
#  Warning: optimization failed at run 14
# |  1186     |  1.013e+0 |  0.05581  |  0.105    |  0.8214   |  0.2406   |  44.23    |  24.9     |  19.23    |  34.62    |
#  Warning: optimization failed at run 13
# |  1187     |  712.7    |  0.951    |  0.256    |  0.8792   |  0.5818   |  48.05    |  93.26    |  16.93    |  85.84    |
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 14
# |  1188     |  3.438e+0 |  0.4561   |  0.8798   |  0.4138   |  0.7972   |  60.82    |  22.46    |  36.34    |  37.65    |
# |  1189     |  139.7    |  0.2812   |  0.9611   |  0.2445   |  0.9568   |  69.84    |  89.51    |  87.1     |  83.7     |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 12
# |  1190     |  6.083e+0 |  0.4547   |  0.3797   |  0.7193   |  0.7064   |  6.777    |  49.38    |  3.444    |  13.47    |
# |  1191     |  1.181e+0 |  0.2536   |  0.7834   |  0.2987   |  0.34     |  20.0     |  63.46    |  90.28    |  48.57    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
# |  1192     |  212.9    |  0.4071   |  0.9041   |  0.3907   |  0.8269   |  99.99    |  83.21    |  75.66    |  57.54    |
#  Warning: optimization failed at run 15
# |  1193     |  2.321e+0 |  0.09646  |  0.7951   |  0.6177   |  0.9928   |  73.5     |  27.99    |  7.747    |  82.94    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
# |  1194     |  128.5    |  0.6077   |  0.1925   |  0.3686   |  0.9672   |  94.02    |  99.05    |  42.01    |  86.45    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
# |  1195     |  316.9    |  0.14     |  0.8851   |  0.8079   |  0.3046   |  90.55    |  52.12    |  59.99    |  64.6     |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
# |  1196     |  1.477e+0 |  0.01995  |  0.4716   |  0.8516   |  0.5465   |  23.09    |  57.97    |  33.17    |  89.62    |
#  Warning: optimization failed at run 13
# |  1197     |  9.301e+0 |  0.1999   |  0.2756   |  0.5909   |  0.9045   |  6.864    |  27.26    |  70.75    |  95.78    |
# |  1198     |  570.1    |  0.09738  |  0.835    |  0.09072  |  0.819    |  66.76    |  0.462    |  4.89     |  79.3     |
# |  1199     |  6.31e+03 |  0.3169   |  0.3445   |  0.9019   |  0.7396   |  54.76    |  13.21    |  26.97    |  70.72    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 10
# |  1200     |  394.2    |  0.06128  |  0.08352  |  0.09435  |  0.9906   |  54.91    |  89.09    |  29.76    |  13.22    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
# |  1201     |  607.5    |  0.7059   |  0.905    |  0.7111   |  0.347    |  54.16    |  59.22    |  90.65    |  60.03    |
# |  1202     |  945.0    |  0.9609   |  0.2817   |  0.1025   |  0.3172   |  75.09    |  6.697    |  47.92    |  94.6     |
# |  1203     |  795.8    |  0.4502   |  0.09791  |  0.472    |  0.3562   |  18.82    |  13.3     |  54.93    |  71.39    |
#  Warning: optimization failed at run 11
# |  1204     |  433.4    |  0.2889   |  0.6017   |  0.2056   |  0.7785   |  8.282    |  75.58    |  28.45    |  23.85    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
# |  1205     |  513.0    |  0.5655   |  0.462    |  0.05437  |  0.6488   |  38.15    |  74.96    |  13.1     |  78.41    |
# |  1206     |  476.1    |  0.8109   |  0.8678   |  0.1329   |  0.8295   |  99.44    |  15.59    |  96.73    |  85.29    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
# |  1207     |  3.835e+0 |  0.7359   |  0.8846   |  0.7052   |  0.1625   |  11.72    |  32.54    |  27.35    |  31.2     |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 13
# |  1208     |  6.561e+0 |  0.5701   |  0.5912   |  0.5588   |  0.5969   |  49.22    |  47.54    |  93.82    |  12.81    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
# |  1209     |  288.6    |  0.09087  |  0.5748   |  0.4761   |  0.9192   |  2.902    |  63.01    |  95.34    |  3.716    |
# |  1210     |  154.7    |  0.9416   |  0.05228  |  0.004497 |  0.4831   |  28.15    |  54.76    |  48.84    |  85.34    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 14
# |  1211     |  5.157e+0 |  0.644    |  0.7509   |  0.339    |  0.06215  |  20.48    |  21.01    |  24.3     |  64.22    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
# |  1212     |  712.0    |  0.2659   |  0.06419  |  0.7539   |  0.7153   |  95.77    |  58.35    |  7.679    |  84.34    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
# |  1213     |  1.083e+0 |  0.2236   |  0.3269   |  0.7451   |  0.3777   |  87.84    |  91.93    |  23.48    |  55.44    |
#  Warning: optimization failed at run 14
# |  1214     |  1.721e+0 |  0.05548  |  0.09796  |  0.5682   |  0.6169   |  69.76    |  78.74    |  11.72    |  49.7     |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
# |  1215     |  453.7    |  0.2814   |  0.7128   |  0.1473   |  0.8707   |  45.88    |  30.18    |  79.59    |  1.182    |
#  Warning: optimization failed at run 9
# |  1216     |  158.5    |  0.8982   |  0.04531  |  0.6274   |  0.08755  |  71.2     |  52.88    |  66.48    |  5.818    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
# |  1217     |  1.433e+0 |  0.3197   |  0.5035   |  0.2118   |  0.7228   |  13.66    |  70.48    |  61.51    |  11.8     |
#  Warning: optimization failed at run 15
# |  1218     |  1.587e+0 |  0.4332   |  0.5917   |  0.4928   |  0.9844   |  41.59    |  34.96    |  76.1     |  35.62    |
#  Warning: optimization failed at run 15
# |  1219     |  1.568e+0 |  0.6079   |  0.8974   |  0.419    |  0.6813   |  7.051    |  14.49    |  19.88    |  93.64    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
# |  1220     |  3.195e+0 |  0.4529   |  0.7959   |  0.3141   |  0.00339  |  27.69    |  6.294    |  36.08    |  50.75    |
# |  1221     |  549.9    |  0.6643   |  0.1352   |  0.6416   |  0.4381   |  99.46    |  9.582    |  70.87    |  7.82     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
# |  1222     |  399.6    |  0.04924  |  0.1625   |  0.502    |  0.2731   |  61.29    |  37.54    |  67.36    |  46.54    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
# |  1223     |  4.177e+0 |  0.1299   |  0.4334   |  0.65     |  0.5125   |  38.9     |  0.4919   |  22.28    |  68.25    |
#  Warning: optimization failed at run 14
# |  1224     |  251.6    |  0.6354   |  0.1923   |  0.8623   |  0.4265   |  59.38    |  44.45    |  63.2     |  44.08    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
# |  1225     |  4.569e+0 |  0.4859   |  0.8091   |  0.5858   |  0.8147   |  28.89    |  58.24    |  84.89    |  71.27    |
#  Warning: optimization failed at run 15
# |  1226     |  692.1    |  0.2942   |  0.9887   |  0.4226   |  0.2027   |  26.55    |  56.8     |  74.23    |  85.64    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 8
# |  1227     |  292.5    |  0.4954   |  0.4491   |  0.3083   |  0.6535   |  91.05    |  40.0     |  79.47    |  68.7     |
# |  1228     |  7.297e+0 |  0.9208   |  0.9419   |  0.9503   |  0.9915   |  44.27    |  20.16    |  16.8     |  21.45    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
# |  1229     |  1.059e+0 |  0.1448   |  0.1641   |  0.4363   |  0.7922   |  54.56    |  65.83    |  28.66    |  12.22    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
# |  1230     |  521.9    |  0.8887   |  0.4229   |  0.3077   |  0.01055  |  12.23    |  39.25    |  48.53    |  97.31    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 14
# |  1231     |  655.1    |  0.7524   |  0.5342   |  0.2354   |  0.3962   |  61.81    |  33.59    |  42.85    |  73.87    |
#  Warning: optimization failed at run 1
# |  1232     |  142.6    |  0.4335   |  0.02857  |  0.314    |  0.8058   |  79.08    |  96.31    |  28.29    |  79.8     |
# |  1233     |  240.3    |  0.09901  |  0.5109   |  0.9104   |  0.06681  |  71.32    |  98.79    |  24.39    |  94.51    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
# |  1234     |  1.03e+03 |  0.04917  |  0.6353   |  0.8429   |  0.3601   |  74.58    |  43.96    |  52.03    |  5.64     |
#  Warning: optimization failed at run 15
# |  1235     |  544.1    |  0.05318  |  0.5041   |  0.7147   |  0.3924   |  16.68    |  82.87    |  75.17    |  13.21    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
# |  1236     |  231.2    |  0.6444   |  0.3581   |  0.04605  |  0.3827   |  85.97    |  1.159    |  93.28    |  74.39    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 8
# |  1237     |  822.9    |  0.7636   |  0.2877   |  0.8183   |  0.2362   |  39.21    |  82.87    |  15.14    |  67.11    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 8
# |  1238     |  2.965e+0 |  0.6329   |  0.9104   |  0.6855   |  0.9834   |  52.91    |  6.376    |  81.24    |  41.46    |
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
# |  1239     |  828.4    |  0.2961   |  0.596    |  0.546    |  0.2448   |  32.02    |  38.25    |  49.36    |  21.48    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
# |  1240     |  240.3    |  0.1362   |  0.7429   |  0.2756   |  0.4944   |  87.98    |  72.71    |  28.26    |  48.74    |
#  Warning: optimization failed at run 14
# |  1241     |  438.7    |  0.1131   |  0.3106   |  0.9366   |  0.2568   |  18.95    |  34.11    |  69.7     |  46.22    |
#  Warning: optimization failed at run 1
# |  1242     |  1.117e+0 |  0.4922   |  0.3386   |  0.8383   |  0.5163   |  17.8     |  95.51    |  70.14    |  9.788    |
# |  1243     |  2.097e+0 |  0.2624   |  0.8031   |  0.9313   |  0.7912   |  27.88    |  45.21    |  92.53    |  91.27    |
#  Warning: optimization failed at run 11
# |  1244     |  245.1    |  0.4223   |  0.4083   |  0.9344   |  0.54     |  64.12    |  65.55    |  92.04    |  53.52    |
#  Warning: optimization failed at run 5
# |  1245     |  414.4    |  0.8611   |  0.1764   |  0.2721   |  0.05687  |  9.425    |  15.27    |  64.5     |  30.09    |
# |  1246     |  2.685e+0 |  0.602    |  0.5624   |  0.3161   |  0.2217   |  73.57    |  11.68    |  57.8     |  74.73    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
# |  1247     |  937.3    |  0.7252   |  0.6547   |  0.04921  |  0.3528   |  22.68    |  99.51    |  23.71    |  3.09     |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
# |  1248     |  5.575e+0 |  0.5354   |  0.6524   |  0.4032   |  0.4355   |  3.949    |  48.27    |  4.2      |  37.56    |
# |  1249     |  267.7    |  0.8573   |  0.4883   |  0.07435  |  0.744    |  44.6     |  1.703    |  64.07    |  48.89    |
# |  1250     |  370.2    |  0.2734   |  0.7104   |  0.9567   |  0.589    |  62.11    |  83.15    |  88.03    |  2.127    |
# |  1251     |  832.4    |  0.01144  |  0.5496   |  0.8377   |  0.2147   |  5.837    |  95.68    |  3.036    |  76.51    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
# |  1252     |  2.306e+0 |  0.7578   |  0.459    |  0.7255   |  0.9667   |  32.95    |  71.25    |  58.99    |  44.36    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  1253     |  293.3    |  0.07033  |  0.2944   |  0.1268   |  0.1358   |  22.31    |  49.44    |  37.91    |  45.1     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
# |  1254     |  449.5    |  0.7276   |  0.4968   |  0.1778   |  0.8996   |  35.5     |  27.84    |  48.96    |  57.28    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
# |  1255     |  187.8    |  0.9572   |  0.7753   |  0.2362   |  0.3866   |  80.59    |  70.97    |  61.71    |  47.89    |
# |  1256     |  250.9    |  0.117    |  0.7164   |  0.1444   |  0.8734   |  81.72    |  89.08    |  10.72    |  29.33    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
# |  1257     |  6.19e+03 |  0.7739   |  0.91     |  0.4322   |  0.3346   |  34.44    |  7.761    |  29.25    |  95.86    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
# |  1258     |  235.6    |  0.2252   |  0.819    |  0.5234   |  0.3669   |  62.18    |  35.49    |  58.94    |  51.06    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
# |  1259     |  519.9    |  0.7319   |  0.7385   |  0.37     |  0.6807   |  73.44    |  83.44    |  83.02    |  31.22    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
# |  1260     |  125.8    |  0.7285   |  0.3988   |  0.895    |  0.1719   |  84.44    |  51.38    |  86.91    |  31.51    |
#  Warning: optimization failed at run 10
# |  1261     |  520.9    |  0.5829   |  0.9864   |  0.1768   |  0.5711   |  72.36    |  36.31    |  96.82    |  0.4358   |
# |  1262     |  200.3    |  0.5722   |  0.7995   |  0.2103   |  0.3472   |  92.79    |  66.45    |  70.7     |  19.62    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 10
# |  1263     |  402.4    |  0.5515   |  0.9138   |  0.1286   |  0.4427   |  44.43    |  71.05    |  29.47    |  40.27    |
#  Warning: optimization failed at run 1
# |  1264     |  1.253e+0 |  0.6642   |  0.2837   |  0.02145  |  0.1236   |  33.24    |  50.0     |  74.75    |  2.879    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  1265     |  8.746e+0 |  0.4594   |  0.5431   |  0.5354   |  0.6058   |  61.55    |  6.634    |  70.46    |  6.365    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 6
# |  1266     |  2.928e+0 |  0.1658   |  0.07214  |  0.4499   |  0.2063   |  50.54    |  73.08    |  9.545    |  9.928    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
# |  1267     |  752.8    |  0.8669   |  0.9098   |  0.06935  |  0.6764   |  21.84    |  67.53    |  53.06    |  55.55    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
# |  1268     |  2.323e+0 |  0.4986   |  0.9601   |  0.6343   |  0.8763   |  72.85    |  28.15    |  62.75    |  77.44    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  1269     |  321.0    |  0.1686   |  0.9267   |  0.09835  |  0.4087   |  35.13    |  76.01    |  39.83    |  20.85    |
#  Warning: optimization failed at run 12
# |  1270     |  4.464e+0 |  0.4462   |  0.657    |  0.6034   |  0.4959   |  25.43    |  62.53    |  47.12    |  32.54    |
# |  1271     |  812.6    |  0.245    |  0.541    |  0.7361   |  0.1807   |  99.68    |  51.93    |  32.51    |  3.131    |
#  Warning: optimization failed at run 12
# |  1272     |  1.045e+0 |  0.1158   |  0.05661  |  0.4634   |  0.3716   |  13.51    |  40.29    |  34.13    |  6.169    |
#  Warning: optimization failed at run 10
# |  1273     |  525.4    |  0.001249 |  0.2859   |  0.3743   |  0.8763   |  68.78    |  21.08    |  76.26    |  64.95    |
# |  1274     |  776.7    |  0.396    |  0.7658   |  0.07494  |  0.8593   |  17.26    |  88.65    |  67.04    |  47.47    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
# |  1275     |  657.2    |  0.2576   |  0.3272   |  0.82     |  0.6728   |  69.68    |  75.23    |  47.56    |  6.632    |
#  Warning: optimization failed at run 8
# |  1276     |  330.2    |  0.5296   |  0.1757   |  0.5655   |  0.9387   |  11.87    |  66.5     |  54.53    |  89.1     |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 1
# |  1277     |  855.2    |  0.6863   |  0.6291   |  0.2199   |  0.8217   |  31.29    |  92.85    |  76.87    |  93.48    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 13
# |  1278     |  454.3    |  0.3781   |  0.3819   |  0.6687   |  0.4987   |  11.67    |  85.57    |  95.28    |  76.02    |
# |  1279     |  189.2    |  0.8797   |  0.9387   |  0.007928 |  0.03676  |  99.32    |  43.06    |  86.61    |  12.58    |
#  Warning: optimization failed at run 11
# |  1280     |  1.906e+0 |  0.009703 |  0.2491   |  0.9774   |  0.3415   |  52.45    |  7.821    |  4.11     |  68.39    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 15
# |  1281     |  1.989e+0 |  0.3079   |  0.7582   |  0.3275   |  0.9824   |  96.46    |  2.587    |  42.38    |  32.64    |
#  Warning: optimization failed at run 15
# |  1282     |  239.6    |  0.7202   |  0.113    |  0.6043   |  0.8584   |  1.924    |  72.43    |  12.21    |  55.19    |
# |  1283     |  550.3    |  0.3073   |  0.9337   |  0.02748  |  0.8354   |  35.71    |  2.019    |  77.74    |  21.19    |
# |  1284     |  576.6    |  0.8707   |  0.2387   |  0.3523   |  0.3784   |  24.85    |  59.67    |  90.26    |  13.0     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
# |  1285     |  1.594e+0 |  0.8134   |  0.7223   |  0.5263   |  0.5174   |  50.51    |  35.01    |  53.73    |  5.516    |
#  Warning: optimization failed at run 14
# |  1286     |  2.39e+03 |  0.4623   |  0.7175   |  0.7511   |  0.5901   |  8.966    |  2.977    |  23.81    |  74.72    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
# |  1287     |  533.3    |  0.5368   |  0.08846  |  0.08501  |  0.5852   |  23.91    |  44.42    |  33.34    |  0.8179   |
#  Warning: optimization failed at run 2
# |  1288     |  450.5    |  0.03563  |  0.6327   |  0.9646   |  0.257    |  90.62    |  45.36    |  42.92    |  30.14    |
# |  1289     |  1.211e+0 |  0.336    |  0.9576   |  0.2374   |  0.8945   |  92.79    |  10.92    |  57.57    |  77.75    |
#  Warning: optimization failed at run 12
# |  1290     |  487.3    |  0.9835   |  0.1921   |  0.3878   |  0.4494   |  7.914    |  69.04    |  6.69     |  44.52    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 15
# |  1291     |  481.1    |  0.1282   |  0.0725   |  0.1463   |  0.2834   |  92.75    |  61.62    |  15.01    |  83.04    |
#  Warning: optimization failed at run 7
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.9259208525151941, 0.7412519220144803, 0.9487267703427024, 0.5493529069040376, 4.932100875623691, 23.483456030828986, 39.37680257472319, 34.04292083344356)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-1c0de620ed6b> in <module>
#       5     n_restarts_optimizer=3,
#       6     acq="ei",
# ----> 7     xi=1e-1
#       8 )
#
# D:\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     172                 iteration += 1
#     173
# --> 174             self.probe(x_probe, lazy=False)
#     175
#     176         self.dispatch(Events.OPTMIZATION_END)
#
# D:\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     110             self._queue.add(params)
#     111         else:
# --> 112             self._space.probe(params)
#     113             self.dispatch(Events.OPTMIZATION_STEP)
#     114
#
# D:\Anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-8-d801a512daad> in utility2(IPTG1, IPTG2, IPTG3, IPTG4, aTc1, aTc2, aTc3, aTc4)
#      57
#      58     gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
# ---> 59     gG2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
#      60     gG2.predict(tgp)
#      61
#
# D:\Jupyter\Final\Final\gaussianprocess.py in findhyperparameters(self, noruns, exitearly, stvals, optmethod, optmessages, quiet, linalgmax)
#     167                         from scipy.optimize import fmin_l_bfgs_b
#     168                         lthf[i,:], lmlml[i], dout= fmin_l_bfgs_b(self.nlml, lth, fprime= self.jacnlml,
# --> 169                                                                 bounds= b, disp= optmessages)
#     170                         linalgerror= linalgmax
#     171                         success[i]= dout['warnflag'] + 1
#
# D:\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# D:\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# D:\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     283     else:
#     284         def func_and_grad(x):
# --> 285             f = fun(x, *args)
#     286             g = jac(x, *args)
#     287             return f, g
#
# D:\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# D:\Jupyter\Final\Final\gaussianprocess.py in nlml(self, lth)
#      93         """
#      94         x, y= self.x, self.y
# ---> 95         k, L= self.kernelmatrix(lth, x)
#      96         al= linalg.cho_solve(L, y)
#      97         halfdetK= np.sum(np.log(np.diagonal(L[0])))
#
# D:\Jupyter\Final\Final\gaussianprocess.py in kernelmatrix(self, lth, x)
#      80         else:
#      81             kn= k + np.exp(lth[-1])*np.identity(len(x))
# ---> 82         L= linalg.cho_factor(kn)
#      83         return k, L
#      84
#
# D:\Anaconda3\lib\site-packages\scipy\linalg\decomp_cholesky.py in cho_factor(a, lower, overwrite_a, check_finite)
#     153     """
#     154     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
# --> 155                          check_finite=check_finite)
#     156     return c, lower
#     157
#
# D:\Anaconda3\lib\site-packages\scipy\linalg\decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      35     overwrite_a = overwrite_a or _datacopied(a1, a)
#      36     potrf, = get_lapack_funcs(('potrf',), (a1,))
# ---> 37     c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      38     if info > 0:
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
#
# KeyboardInterrupt:

# %%
# Save results obtained
with open('config4sGFPNU15EI.optim', 'wb') as config_optim_file:
 
    pickle.dump(optimizer3, config_optim_file)

# %%
# Best utility value generated
print(optimizer3.max)
# Out:
# {'target': 729700.3139234037, 'params': {'IPTG1': 0.9207676022427584, 'IPTG2': 0.9419336396325302, 'IPTG3': 0.9503286921608789, 'IPTG4': 0.9914952791208878, 'aTc1': 44.26618657881474, 'aTc2': 20.15976981361772, 'aTc3': 16.803632423538083, 'aTc4': 21.44912559828025}}

# %% [markdown]
# Plot best utility value so far per iteration:

# %%
v = []
for i, res in enumerate(optimizer3.res):
    v.append(res['target'])
    
vn = []
for i, val in enumerate(v):
    mv = max(v[0:i+1])
    vn.append(mv)
    
plt.figure()
plt.plot(vn)
plt.plot(v)
plt.show()

# %%
df = pd.DataFrame({
    'CFV': v})
df.to_csv('CFV_Iter_4S_GFPNU15EI.csv')

df = pd.DataFrame({
    'CFV': vn})
df.to_csv('bestCFV_Iter_4S_GFPNU15EI.csv')

# %% [markdown]
# ### Check results with plot

# %%
inputs = [round(optimizer3.max['params']['IPTG1'], 2)+1e-7, int(optimizer3.max['params']['aTc1'])+1e-7, 
          round(optimizer3.max['params']['IPTG2'], 2)+1e-7, int(optimizer3.max['params']['aTc2'])+1e-7, 
          round(optimizer3.max['params']['IPTG3'], 2)+1e-7, int(optimizer3.max['params']['aTc3'])+1e-7, 
          round(optimizer3.max['params']['IPTG4'], 2)+1e-7, int(optimizer3.max['params']['aTc4'])+1e-7]

ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
sp = [int(i) for i in list(np.linspace(0,(24*60),5))]
t =  np.linspace(0,(24*60),(24*60)+1)

pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))

# Simulation of the system for the two models and extract of results
solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')

RFP_M1 = solM1[:,0:len(pM1[:,1])]
GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]

RFP_M2 = solM2[:,0:len(pM2[:,1])]
GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]

# %%
t = np.linspace(0,(24*60),round(24*60/5)+1)

plt.figure()
lines = plt.plot(t, GFP_M2, 'c')
plt.text((24*60)+1, 800, "Model 2", bbox=dict(facecolor='c'))
plt.title("Average")
lines2 = plt.plot(t, GFP_M1, 'g')
plt.text((24*60)+1, 600, "Model 1", bbox=dict(facecolor='g'))

plt.show()
plt.figure()
plt.plot(t, RFP_M2, 'c')

plt.text((24*60)+1, 500, "Model 2", bbox=dict(facecolor='c'))
plt.text((24*60)+1, 40, "Model 1", bbox=dict(facecolor='r'))
plt.plot(t, RFP_M1, 'r')
plt.show()

# %% [markdown]
# ### Check utility decomposition results

# %%
# Gaussian Process Regression and Reduction

# Means and standard deviations for each time point for each species and for each model
tgp = np.linspace(0,(24*60),(24*60/5)+1)

muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
sdR3 = RFP_M2.std(axis = 1)
muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
sdG3 = GFP_M2.std(axis = 1)
muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
sdR2 = RFP_M1.std(axis = 1)
muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
sdG2 = GFP_M1.std(axis = 1)

# Gaussian Process regression
gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
gR3.findhyperparameters(noruns=15)
gR3.predict(tgp)

gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
gG3.findhyperparameters(noruns=15)
gG3.predict(tgp)

gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
gR2.findhyperparameters(noruns=15)
gR2.predict(tgp)

gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
gG2.findhyperparameters(noruns=15)
gG2.predict(tgp)

# %%
muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R2.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G2.predict(tref)

# %%
bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
u_B = (bdR*bdG)

# %%
print("The BD for RFP is: ", str(bdR))
print("The BD for GFP is: ", str(bdG))
print("The multiplicative BD is: ", str(u_B))
