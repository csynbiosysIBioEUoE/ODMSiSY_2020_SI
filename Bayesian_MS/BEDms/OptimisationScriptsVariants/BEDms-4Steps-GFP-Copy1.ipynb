# %% [markdown]
# # Bayesian Experimental Design for model selection

# %% [markdown]
# Script used to perform a 4 step optimisation with a Matern Kernel with nu=0.5. To change the Kernel, this needs to be done in the source code of the package used since there is no apparent parameter in the functions to modulate it.
#
#    ............................................................................................................................................................................................................................................

# %% [markdown]
# ### Import Required libraries

# %%
import numpy as np
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import seaborn as sns
from numba import jit
import gaussianprocess as gp
from fitderiv import fitderiv
import genutils as gu
import datetime
from bayes_opt import BayesianOptimization
from bayes_opt.observer import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs
import pickle

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import math

# %% [markdown]
# ### Model 1 Functions (ODEs, Steady State and Event based representation)
# * Lugagne et. al. Model

# %%
@jit
def model1(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    
    if u_IPTG > y[0]:
        dInd_dt[0]=k_in_IPTG*(u_IPTG-y[0])
    else:
        dInd_dt[0]=k_out_IPTG*(u_IPTG-y[0])
    
    if u_aTc > y[2]:
        dInd_dt[1]=k_in_aTc*(u_aTc-y[1])
    else:
        dInd_dt[1]=k_out_aTc*(u_aTc-y[1])
    
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState1(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode1(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState1(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model1,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 2 Functions (ODEs, Steady State and Event based representation)
# * Intermediate Model (Single rate, no degradation)

# %%
@jit
def model2(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0]);
    dInd_dt[1] = k_aTc*(u_aTc-y[1]);
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState2(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode2(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState2(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model2,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 3 Functions (ODEs, Steady State and Event based representation)
# * Lucia's Model

# %%
@jit
def model3(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0])-0.0165*y[0];
    dInd_dt[1] = k_aTc*(u_aTc-y[1])-0.0165*y[1];
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState3(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(4)
    alpha[0] = (k_IPTG*u_IPTG)/(k_IPTG+0.0165)
    alpha[1] = (k_aTc*u_aTc)/(k_aTc+0.0165)
    alpha[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(alpha[1]/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(alpha[0]/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode3(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    
    y_al = SteadyState3(p,ivss) # Calculation of initial guesses for steady state
    
    ssv = odeint(model3,y_al,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]
        
        
        
    
    return(final)

# %% [markdown]
# ### Functions to simulate the 3 models for all parameter draws

# %%
def solveALL (ts, pD, sp, inputs, ivss, pre, model):
    
    AllSol = np.empty((len(ts),len(pD[:,1])*2))
    AllSolTest = np.empty(((round(len(ts)/5)+1),len(pD[:,1])*2))
    for drawInd in range(0,len(pD[:,1])):
        
        p = pD[drawInd,:]
        if model == 'M1':
            temp = solve_coupled_ode1(ts, p, sp, inputs, ivss, pre)
        elif model == 'M2':
            temp = solve_coupled_ode2(ts, p, sp, inputs, ivss, pre)
        elif model == 'M3':
            temp = solve_coupled_ode3(ts, p, sp, inputs, ivss, pre)
        else:
            print('Please, select a correct model as M1, M2 or M3 for the desired one')

        AllSolTest[:,drawInd] = temp[:,2][::5]
        AllSolTest[:,drawInd+(len(pD[:,1]))] = temp[:,3][::5]

    return(AllSolTest)

# %% [markdown]
# ### Example:

# %%
ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
inputs = np.empty(18) # What needs to be optimised    --> example: [1e-7,100,1,1e-7]*4+[1e-7,100]
evnT = [int(i) for i in list(np.linspace(0,(24*60),10))]
t = np.linspace(0,(24*60),(24*60)+1)
pM3 = np.asarray(pd.read_csv("ParametersCSV/draws_ALL_Model3.stan.csv"))

# %%
p = pM3[0:5,:]
test = solveALL(t,p,evnT,[1e-7,100,1,1e-7]*4+[1e-7,100],ivss,pre, 'M3')
plt.figure()
plt.plot(t[::5], test[:,0:5], 'r')
plt.plot(t[::5], test[:,5:10], 'g')
plt.show()

# %% [markdown]
# ### Bhattacharyya distance function:

# %%
def BhattacharyyaDist (mu1, mu2, sd1, sd2):
    E = (sd1+sd2)/2
    Em1 = np.linalg.inv(E)
    dE = abs(np.linalg.det(E))

    t1 = np.matrix.transpose((np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))))
    t2 = np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))
    
    ft = (1/8)*t1*Em1*t2
    st = dE/np.sqrt(abs(np.linalg.det(sd1))*abs(np.linalg.det(sd2)))
    
    bhd = ft+0.5*np.log(st)
    
    return(float(bhd))

# %% [markdown]
# ### Definition of the utility function:

# %%
def utility2 (IPTG1, IPTG2, IPTG3, IPTG4,
             aTc1, aTc2, aTc3, aTc4):
    
    # Definition of inputs for the ODEs
        
    inputs = [round(IPTG1,2)+1e-7, int(aTc1)+1e-7, round(IPTG2,2)+1e-7, int(aTc2)+1e-7,
              round(IPTG3,2)+1e-7, int(aTc3)+1e-7, round(IPTG4,2)+1e-7, int(aTc4)+1e-7]
    
    # Initial values for steady state and inputs
    ivss = [1,1e-7,1363.193,28.510]
    pre = [1,1e-7]
    # Event switches and inputs
    sp = [int(i) for i in list(np.linspace(0,(24*60),5))]
    t =  np.linspace(0,(24*60),(24*60)+1)
    
    # load parameter draws for the two models
    pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
    pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))
    
    # Simulation of the system for the two models and extract of results
    solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
    solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')
    
    RFP_M1 = solM1[:,0:len(pM1[:,1])]
    GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]
    
    RFP_M2 = solM2[:,0:len(pM2[:,1])]
    GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]
    
    # Gaussian Process Regression and Reduction
    
    # Means and standard deviations for each time point for each species and for each model
    tgp = np.linspace(0,(24*60),round(24*60/5)+1)
    
#     muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
#     sdR3 = RFP_M2.std(axis = 1)
    muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
    sdG3 = GFP_M2.std(axis = 1)
#     muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
#     sdR2 = RFP_M1.std(axis = 1)
    muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
    sdG2 = GFP_M1.std(axis = 1)

    # Gaussian Process regression
#     gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
#     gR3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
#     gR3.predict(tgp)
    
    gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
    gG3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG3.predict(tgp)
    
#     gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
#     gR2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
#     gR2.predict(tgp)
    
    gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
    gG2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG2.predict(tgp)
    
    # Time points reduction

#     muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
#     tref = list(tgp[::10])

#     g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
#     g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
#     g2R3.predict(tref)

    
#     muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
#     tref = list(tgp[::10])

#     g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
#     g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
#     g2R2.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
    tref = list(tgp[::10])

    g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G3.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
    tref = list(tgp[::10])

    
    g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G2.predict(tref)

    
    # Bhattacharyya distance:
#     bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
    bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
    
    if bdG == float("inf"):
        bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp+(np.identity(g2G3.covp.shape[1])*1e-6), 
                            g2G2.covp+(np.identity(g2G2.covp.shape[1])*1e-6))
    
    # Utility function value
    u_B = (bdG)

    return(u_B)

# %% [markdown]
# ### Bayesian Optimisation:

# %%
# Bounded region of parameter space

pbounds = {'IPTG1': (0, 1), 'IPTG2': (0, 1), 'IPTG3': (0, 1), 'IPTG4': (0, 1),
           'aTc1': (0, 100), 'aTc2': (0, 100), 'aTc3': (0, 100), 'aTc4': (0, 100)}

# %% [markdown]
# Setting Bayesian Optimisation with our utility function

# %%
optimizer3 = BayesianOptimization(
    f=utility2,
    pbounds=pbounds,
    verbose=2, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1324,
)

# %% [markdown]
# Begin optimisation rutine

# %%
optimizer3.maximize(
    init_points=0,
    n_iter=1000,
    alpha=1e-2,
    n_restarts_optimizer=3, 
    kappa = 10
#     acq="ei", 
#     xi=1e-4
)
# Out:
# |   iter    |  target   |   IPTG1   |   IPTG2   |   IPTG3   |   IPTG4   |   aTc1    |   aTc2    |   aTc3    |   aTc4    |
# -------------------------------------------------------------------------------------------------------------------------
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
# |  1734     |  1.832e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
# |  1735     |  1.82e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1736     |  1.806e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
# |  1737     |  1.803e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1738     |  1.815e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
# |  1739     |  1.842e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 14
# |  1740     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
# |  1741     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 15
# |  1742     |  1.806e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
# |  1743     |  1.796e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 13
# |  1744     |  1.802e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
# |  1745     |  1.805e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
# |  1746     |  1.796e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
# |  1747     |  1.796e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
# |  1748     |  1.806e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 2
# |  1749     |  1.787e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
# |  1750     |  1.796e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 1
# |  1751     |  1.821e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 15
# |  1752     |  1.829e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1753     |  1.803e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
# |  1754     |  1.809e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1755     |  1.821e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1756     |  1.782e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 15
# |  1757     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1758     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
# |  1759     |  1.847e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1760     |  1.782e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1761     |  1.805e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1762     |  1.798e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1763     |  1.805e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1764     |  1.81e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 11
# |  1765     |  1.817e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
# |  1766     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 11
# |  1767     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
# |  1768     |  1.805e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1769     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
# |  1770     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 15
# |  1771     |  1.804e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 10
# |  1772     |  1.8e+05  |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1773     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
# |  1774     |  1.833e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
# |  1775     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 14
# |  1776     |  1.817e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
# |  1777     |  1.809e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
# |  1778     |  1.826e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 10
# |  1779     |  1.793e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
# |  1780     |  1.789e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1781     |  1.795e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
# |  1782     |  1.813e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1783     |  1.794e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
# |  1784     |  1.783e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
# |  1785     |  1.81e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
# |  1786     |  1.816e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1787     |  1.798e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
# |  1788     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
# |  1789     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1790     |  1.81e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
# |  1791     |  1.796e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1792     |  1.813e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
# |  1793     |  1.812e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1794     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1795     |  1.812e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1796     |  1.813e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
# |  1797     |  1.802e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
# |  1798     |  1.796e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
# |  1799     |  1.832e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
# |  1800     |  1.827e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1801     |  1.799e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1802     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
# |  1803     |  1.824e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
# |  1804     |  1.789e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1805     |  1.79e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1806     |  1.794e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
# |  1807     |  1.818e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  1808     |  1.832e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1809     |  1.831e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1810     |  1.809e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
# |  1811     |  1.83e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1812     |  1.8e+05  |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
# |  1813     |  1.846e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 10
# |  1814     |  1.796e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1815     |  1.815e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1816     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
# |  1817     |  1.82e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  1818     |  1.804e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 13
# |  1819     |  1.836e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
# |  1820     |  1.809e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1821     |  1.806e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 14
# |  1822     |  1.814e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
# |  1823     |  1.803e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1824     |  1.817e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 3
# |  1825     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 13
# |  1826     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1827     |  1.802e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
# |  1828     |  1.815e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 13
# |  1829     |  1.813e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 13
# |  1830     |  1.823e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 4
# |  1831     |  1.817e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
# |  1832     |  1.814e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
# |  1833     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
# |  1834     |  1.802e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
# |  1835     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 6
# |  1836     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
# |  1837     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1838     |  1.802e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1839     |  1.814e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1840     |  1.798e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1841     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
# |  1842     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 13
# |  1843     |  1.812e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
# |  1844     |  1.827e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 2
# |  1845     |  1.775e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
# |  1846     |  1.8e+05  |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1847     |  1.786e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
# |  1848     |  1.815e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
# |  1849     |  1.818e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1850     |  1.785e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 8
# |  1851     |  1.821e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1852     |  1.81e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
# |  1853     |  1.813e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
# |  1854     |  1.782e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
# |  1855     |  1.822e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
# |  1856     |  1.843e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
# |  1857     |  1.784e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
# |  1858     |  1.802e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 12
# |  1859     |  1.818e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
# |  1860     |  1.809e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
# |  1861     |  1.823e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1862     |  1.805e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1863     |  1.803e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1864     |  1.826e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
# |  1865     |  1.792e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
# |  1866     |  1.829e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
# |  1867     |  1.823e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 3
# |  1868     |  1.814e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1869     |  1.814e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
# |  1870     |  1.802e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 14
# |  1871     |  1.848e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
# |  1872     |  1.821e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
# |  1873     |  1.805e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1874     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 2
# |  1875     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
# |  1876     |  1.825e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1877     |  1.808e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1878     |  1.822e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
# |  1879     |  1.804e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 11
# |  1880     |  1.84e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 14
# |  1881     |  1.806e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
# |  1882     |  1.803e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
# |  1883     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1884     |  1.805e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 1
# |  1885     |  1.794e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
# |  1886     |  1.817e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
# |  1887     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1888     |  1.806e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1889     |  1.81e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1890     |  1.78e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 4
# |  1891     |  1.824e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
# |  1892     |  1.792e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
# |  1893     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
# |  1894     |  1.817e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
# |  1895     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
# |  1896     |  1.794e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
# |  1897     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
# |  1898     |  1.792e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
# |  1899     |  1.81e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 13
# |  1900     |  1.786e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1901     |  1.817e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1902     |  1.825e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
# |  1903     |  1.817e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
# |  1904     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1905     |  1.828e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1906     |  1.835e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 4
# |  1907     |  1.814e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
# |  1908     |  1.799e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1909     |  1.81e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1910     |  1.809e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 1
# |  1911     |  1.84e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
# |  1912     |  1.798e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
# |  1913     |  1.801e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
# |  1914     |  1.812e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
# |  1915     |  1.825e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 11
# |  1916     |  1.791e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1917     |  1.856e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 1
# |  1918     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
# |  1919     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1920     |  1.792e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 14
# |  1921     |  1.831e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
# |  1922     |  1.804e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1923     |  1.824e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 13
# |  1924     |  1.818e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
# |  1925     |  1.847e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
# |  1926     |  1.826e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1927     |  1.832e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1928     |  1.815e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
# |  1929     |  1.798e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1930     |  1.808e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1931     |  1.811e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 4
# |  1932     |  1.816e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1933     |  1.837e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 4
# |  1934     |  1.794e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
# |  1935     |  1.794e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1936     |  1.845e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1937     |  1.788e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 4
# |  1938     |  1.842e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
# |  1939     |  1.808e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 7
# |  1940     |  1.806e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 9
# |  1941     |  1.799e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 11
# |  1942     |  1.807e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 8
# |  1943     |  1.813e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
# |  1944     |  1.831e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1945     |  1.826e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
# |  1946     |  1.8e+05  |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1947     |  1.83e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 15
# |  1948     |  1.809e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1949     |  1.796e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1950     |  1.797e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# |  1951     |  1.81e+05 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 14
# |  1952     |  1.784e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
# |  1953     |  1.801e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 2
# |  1954     |  1.819e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
# |  1955     |  1.784e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 2
# |  1956     |  1.809e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 14
# |  1957     |  1.802e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 7
# |  1958     |  1.798e+0 |  0.935    |  0.8053   |  0.7899   |  0.6969   |  45.74    |  20.32    |  8.594    |  18.58    |
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     168             try:
# --> 169                 x_probe = next(self._queue)
#     170             except StopIteration:
#
# D:\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in __next__(self)
#      25         if self.empty:
# ---> 26             raise StopIteration("Queue is empty, no more objects to retrieve.")
#      27         obj = self._queue[0]
#
# StopIteration: Queue is empty, no more objects to retrieve.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-18f0ca68120f> in <module>
#       4     alpha=1e-2,
#       5     n_restarts_optimizer=3,
# ----> 6     kappa = 10
#       7 #     acq="ei",
#       8 #     xi=1e-4
#
# D:\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     169                 x_probe = next(self._queue)
#     170             except StopIteration:
# --> 171                 x_probe = self.suggest(util)
#     172                 iteration += 1
#     173
#
# D:\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in suggest(self, utility_function)
#     130             y_max=self._space.target.max(),
#     131             bounds=self._space.bounds,
# --> 132             random_state=self._random_state
#     133         )
#     134
#
# D:\Anaconda3\lib\site-packages\bayes_opt\util.py in acq_max(ac, gp, y_max, bounds, random_state, n_warmup, n_iter)
#      44     x_tries = random_state.uniform(bounds[:, 0], bounds[:, 1],
#      45                                    size=(n_warmup, bounds.shape[0]))
# ---> 46     ys = ac(x_tries, gp=gp, y_max=y_max)
#      47     x_max = x_tries[ys.argmax()]
#      48     max_acq = ys.max()
#
# D:\Anaconda3\lib\site-packages\bayes_opt\util.py in utility(self, x, gp, y_max)
#      95     def utility(self, x, gp, y_max):
#      96         if self.kind == 'ucb':
# ---> 97             return self._ucb(x, gp, self.kappa)
#      98         if self.kind == 'ei':
#      99             return self._ei(x, gp, y_max, self.xi)
#
# D:\Anaconda3\lib\site-packages\bayes_opt\util.py in _ucb(x, gp, kappa)
#     105         with warnings.catch_warnings():
#     106             warnings.simplefilter("ignore")
# --> 107             mean, std = gp.predict(x, return_std=True)
#     108
#     109         return mean + kappa * std
#
# D:\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py in predict(self, X, return_std, return_cov)
#     349                 y_var = self.kernel_.diag(X)
#     350                 y_var -= np.einsum("ij,ij->i",
# --> 351                                    np.dot(K_trans, self._K_inv), K_trans)
#     352
#     353                 # Check if any of the variances is negative because of
#
# KeyboardInterrupt:

# %%
# Save results obtained
with open('config4sGFP1N05.optim', 'wb') as config_optim_file:
    
    pickle.dump(optimizer, config_optim_file)

# %% [markdown]
# Plot best utility value so far per iteration:

# %%
v = []
for i, res in enumerate(optimizer3.res):
    v.append(res['target'])
    
vn = []
for i, val in enumerate(v):
    mv = max(v[0:i+1])
    vn.append(mv)
    
plt.figure()
plt.plot(vn)
plt.plot(v)
plt.show()

# %%
df = pd.DataFrame({
    'CFV': v})
df.to_csv('CFV_Iter_4S_GFP_NU05.csv')

# %%
df = pd.DataFrame({
    'CFV': vn})
df.to_csv('bestCFV_Iter_4S_GFP_NU05.csv')

# %% [markdown]
# ### Check results with plot

# %%
inputs = [round(optimizer3.max['params']['IPTG1'], 2)+1e-7, int(optimizer3.max['params']['aTc1'])+1e-7, 
          round(optimizer3.max['params']['IPTG2'], 2)+1e-7, int(optimizer3.max['params']['aTc2'])+1e-7, 
          round(optimizer3.max['params']['IPTG3'], 2)+1e-7, int(optimizer3.max['params']['aTc3'])+1e-7, 
          round(optimizer3.max['params']['IPTG4'], 2)+1e-7, int(optimizer3.max['params']['aTc4'])+1e-7]

ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
sp = [int(i) for i in list(np.linspace(0,(24*60),5))]
t =  np.linspace(0,(24*60),(24*60)+1)

pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))

# Simulation of the system for the two models and extract of results
solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')

RFP_M1 = solM1[:,0:len(pM1[:,1])]
GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]

RFP_M2 = solM2[:,0:len(pM2[:,1])]
GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]

# %%
t = np.linspace(0,(24*60),round(24*60/5)+1)

plt.figure()
lines = plt.plot(t, GFP_M2, 'c')
plt.text((24*60)+1, 800, "Model 2", bbox=dict(facecolor='c'))
plt.title("Average")
lines2 = plt.plot(t, GFP_M1, 'g')
plt.text((24*60)+1, 600, "Model 1", bbox=dict(facecolor='g'))

plt.show()
plt.figure()
plt.plot(t, RFP_M2, 'c')

plt.text((24*60)+1, 500, "Model 2", bbox=dict(facecolor='c'))
plt.text((24*60)+1, 40, "Model 1", bbox=dict(facecolor='r'))
plt.plot(t, RFP_M1, 'r')
plt.show()

# %% [markdown]
# ### Check utility decomposition results

# %%
# Gaussian Process Regression and Reduction

# Means and standard deviations for each time point for each species and for each model
tgp = np.linspace(0,(24*60),(24*60/5)+1)

muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
sdR3 = RFP_M2.std(axis = 1)
muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
sdG3 = GFP_M2.std(axis = 1)
muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
sdR2 = RFP_M1.std(axis = 1)
muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
sdG2 = GFP_M1.std(axis = 1)

# Gaussian Process regression
gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
gR3.findhyperparameters(noruns=15)
gR3.predict(tgp)

gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
gG3.findhyperparameters(noruns=15)
gG3.predict(tgp)

gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
gR2.findhyperparameters(noruns=15)
gR2.predict(tgp)

gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
gG2.findhyperparameters(noruns=15)
gG2.predict(tgp)
# Out:
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 11

# %%
muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R2.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G2.predict(tref)
# Out:
#  Warning: optimization failed at run 4

# %%
# Extract time points from flat regions
def textract(mu, cov):

    ft = np.random.multivariate_normal(mu, cov)
    ft2 = np.ndarray.tolist(ft[0:len(ft)-1])
    ft2.insert(0,0)
    ft2 = np.asarray(ft2)
    
    sub = abs(ft[::10]-ft2[::10])
    inde0 = []
    for i in range(0,len(sub)):
        if sub[i] < 1.5:
            inde0.append(i)

    nwar = []
    u = 0
    for j in range(0,len(inde0)-6, 6):
        if sorted(inde0[j:j+6]) == list(range(min(inde0[j:j+6]), max(inde0[j:j+6])+1)):
            l = inde0[j:j+6]
            nw = inde0[j:j+6][::2]
            for k in nw:
                l.remove(k)
            nwar.append(l)#[u] = l
            u += 1
    return(nwar)

# %%
bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
u_B = (bdR*bdG)

# %%
print("The BD for RFP is: ", str(bdR))
print("The BD for GFP is: ", str(bdG))
print("The multiplicative BD is: ", str(u_B))
print("The average BD is: ", str((bdR+bdG)/2))
