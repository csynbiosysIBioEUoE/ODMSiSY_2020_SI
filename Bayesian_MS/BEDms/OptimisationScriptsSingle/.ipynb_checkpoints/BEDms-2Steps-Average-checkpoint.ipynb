# %% [markdown]
# # Bayesian Experimental Design for model selection

# %% [markdown]
# Script used to perform optimisation where a 2 step experiment is being design considering the average of the Bhattacharyya distances of RFP and GFP for the two models
#
#    ............................................................................................................................................................................................................................................

# %% [markdown]
# ### Import Required libraries

# %%
import numpy as np
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import seaborn as sns
from numba import jit
import gaussianprocess as gp
from fitderiv import fitderiv
import genutils as gu
import datetime
from bayes_opt import BayesianOptimization
from bayes_opt.observer import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs
import pickle

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import math

# %% [markdown]
# ### Model 1 Functions (ODEs, Steady State and Event based representation)
# * Lugagne et. al. Model

# %%
@jit
def model1(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    
    if u_IPTG > y[0]:
        dInd_dt[0]=k_in_IPTG*(u_IPTG-y[0])
    else:
        dInd_dt[0]=k_out_IPTG*(u_IPTG-y[0])
    
    if u_aTc > y[2]:
        dInd_dt[1]=k_in_aTc*(u_aTc-y[1])
    else:
        dInd_dt[1]=k_out_aTc*(u_aTc-y[1])
    
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState1(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_in_IPTG = p[0]
    k_out_IPTG = p[1]
    k_in_aTc = p[2]
    k_out_aTc = p[3]
    k_L_pm0 = p[4]
    k_L_pm = p[5]
    theta_T = p[6]
    theta_aTc = p[7]
    n_aTc = p[8]
    n_T = p[9];
    k_T_pm0 = p[10]
    k_T_pm = p[11]
    theta_L = p[12]
    theta_IPTG = p[13]
    n_IPTG = p[14]
    n_L = p[15]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode1(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState1(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model1,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model1,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 2 Functions (ODEs, Steady State and Event based representation)
# * Intermediate Model (Single rate, no degradation)

# %%
@jit
def model2(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0]);
    dInd_dt[1] = k_aTc*(u_aTc-y[1]);
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState2(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(2)
    alpha[0] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(u_aTc/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[1] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(u_IPTG/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode2(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    Y0 = np.empty(4)
    
    y_al = SteadyState2(p,ivss) # Calculation of initial guesses for steady state
    Y0[0] = pre[0]
    Y0[1] = pre[1]
    Y0[2] = y_al[0]
    Y0[3] = y_al[1]
    ssv = odeint(model2,Y0,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model2,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]

    return(final)

# %% [markdown]
# ### Model 3 Functions (ODEs, Steady State and Event based representation)
# * Lucia's Model

# %%
@jit
def model3(y,t,p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs
    dInd_dt = np.empty(4).tolist()
    dInd_dt[0] = k_IPTG*(u_IPTG-y[0])-0.0165*y[0];
    dInd_dt[1] = k_aTc*(u_aTc-y[1])-0.0165*y[1];
    dInd_dt[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+(y[3]/theta_T*1/(1+(y[1]/theta_aTc)**n_aTc))**n_T))))-0.0165*y[2];
    dInd_dt[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+(y[2]/theta_L*1/(1+(y[0]/theta_IPTG)**n_IPTG))**n_L))))-0.0165*y[3];
    
    # Results
    return dInd_dt

def SteadyState3(p,I):
    
    # Inputs
    u_IPTG = I[0]
    u_aTc = I[1]
    preRFP = I[2]
    preGFP = I[3]
    
    # Parameters
    k_IPTG = p[0]
    k_aTc = p[1]
    k_L_pm0 = p[2]
    k_L_pm = p[3]
    theta_T = p[4]
    theta_aTc = p[5]
    n_aTc = p[6]
    n_T = p[7];
    k_T_pm0 = p[8]
    k_T_pm = p[9]
    theta_L = p[10]
    theta_IPTG = p[11]
    n_IPTG = p[12]
    n_L = p[13]
    
    # ODEs steady state equations
    alpha = np.empty(4)
    alpha[0] = (k_IPTG*u_IPTG)/(k_IPTG+0.0165)
    alpha[1] = (k_aTc*u_aTc)/(k_aTc+0.0165)
    alpha[2] = ((1/0.1386)*(k_L_pm0+(k_L_pm/(1+((preGFP/theta_T)*1/(1+(alpha[1]/theta_aTc)**n_aTc))**n_T))))/0.0165
    alpha[3] = ((1/0.1386)*(k_T_pm0+(k_T_pm/(1+((preRFP/theta_L)*1/(1+(alpha[0]/theta_IPTG)**n_IPTG))**n_L))))/0.0165
    
    # Results
    return alpha


def solve_coupled_ode3(ts, p, sp, inputs, ivss, pre):
    maxtime = len(ts);
    Nsp = len(sp);
    Nevents = len(sp)-1;
    Neq = 4;
    p = p
    
    final = np.zeros((maxtime,Neq))
    
    y_al = SteadyState3(p,ivss) # Calculation of initial guesses for steady state
    
    ssv = odeint(model3,y_al,np.linspace(0,24*60,(24*60)+1),args=(p,pre), rtol=1e-9,atol=1e-9, tcrit=np.array(range(0,24*60+1)))
    
    y0 = ssv[24*60,:]
    
    initialV = y0
    i = 0
    
    for q in range(0,Nevents):
        
        lts = len(ts[(sp[q]+1):sp[q+1]+1])  # General way to define the number of elements in each event series
        Tevent = ts[(sp[q]):sp[q+1]+1]  # General way to extract the times of each event
        I = inputs[i:(i+2)]
        
        if q == 0:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))#, full_output =1)
            
        else:
            
            part1 = odeint(model3,initialV,ts[(sp[q]):sp[q+1]+1],args=(p,I), 
                         rtol=1e-9,atol=1e-9, tcrit=np.array(range((sp[q]),sp[q+1])))
        
        initialV = part1[lts]
        i=i+2;
        
        for d in range((sp[q]),(sp[q]+lts+1)):
            
            final[d,:] = part1[d-sp[q]]
        
        
        
    
    return(final)

# %% [markdown]
# ### Functions to simulate the 3 models for all parameter draws

# %%
def solveALL (ts, pD, sp, inputs, ivss, pre, model):
    
    AllSol = np.empty((len(ts),len(pD[:,1])*2))
    AllSolTest = np.empty(((round(len(ts)/5)+1),len(pD[:,1])*2))
    for drawInd in range(0,len(pD[:,1])):
        
        p = pD[drawInd,:]
        if model == 'M1':
            temp = solve_coupled_ode1(ts, p, sp, inputs, ivss, pre)
        elif model == 'M2':
            temp = solve_coupled_ode2(ts, p, sp, inputs, ivss, pre)
        elif model == 'M3':
            temp = solve_coupled_ode3(ts, p, sp, inputs, ivss, pre)
        else:
            print('Please, select a correct model as M1, M2 or M3 for the desired one')

        AllSolTest[:,drawInd] = temp[:,2][::5]
        AllSolTest[:,drawInd+(len(pD[:,1]))] = temp[:,3][::5]

    return(AllSolTest)

# %% [markdown]
# ### Example:

# %%
ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
inputs = np.empty(18) # What needs to be optimised    --> example: [1e-7,100,1,1e-7]*4+[1e-7,100]
evnT = [int(i) for i in list(np.linspace(0,(24*60),10))]
t = np.linspace(0,(24*60),(24*60)+1)
pM3 = np.asarray(pd.read_csv("ParametersCSV/draws_ALL_Model3.stan.csv"))

# %%
p = pM3[0:5,:]
test = solveALL(t,p,evnT,[1e-7,100,1,1e-7]*4+[1e-7,100],ivss,pre, 'M3')
plt.figure()
plt.plot(t[::5], test[:,0:5], 'r')
plt.plot(t[::5], test[:,5:10], 'g')
plt.show()

# %% [markdown]
# ### Bhattacharyya distance function:

# %%
def BhattacharyyaDist (mu1, mu2, sd1, sd2):
    E = (sd1+sd2)/2
    Em1 = np.linalg.inv(E)
    dE = abs(np.linalg.det(E))

    t1 = np.matrix.transpose((np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))))
    t2 = np.matrix.transpose(np.matrix(mu1))-np.matrix.transpose(np.matrix(mu2))
    
    ft = (1/8)*t1*Em1*t2
    st = dE/np.sqrt(abs(np.linalg.det(sd1))*abs(np.linalg.det(sd2)))
    
    bhd = ft+0.5*np.log(st)
    
    return(float(bhd))

# %%
# Extract time points from flat regions
def textract(mu, cov):

    ft = np.random.multivariate_normal(mu, cov)
    ft2 = np.ndarray.tolist(ft[0:len(ft)-1])
    ft2.insert(0,0)
    ft2 = np.asarray(ft2)
    
    sub = abs(ft[::10]-ft2[::10])
    inde0 = []
    for i in range(0,len(sub)):
        if sub[i] < 0.4:
            inde0.append(i)

    nwar = []
    u = 0
    for j in range(0,len(inde0)-6, 6):
        if sorted(inde0[j:j+6]) == list(range(min(inde0[j:j+6]), max(inde0[j:j+6])+1)):
            l = inde0[j:j+6]
            nw = inde0[j:j+6][::2]
            for k in nw:
                l.remove(k)
            nwar.append(l)#[u] = l
            u += 1
    return(nwar)

# %% [markdown]
# ### Definition of the utility function:

# %%
def utility2 (IPTG1, IPTG2,
             aTc1, aTc2):
    
    # Definition of inputs for the ODEs
        
    inputs = [round(IPTG1,2)+1e-7, int(aTc1)+1e-7, round(IPTG2,2)+1e-7, int(aTc2)+1e-7]
    
    # Initial values for steady state and inputs
    ivss = [1,1e-7,1363.193,28.510]
    pre = [1,1e-7]
    # Event switches and inputs
    sp = [int(i) for i in list(np.linspace(0,(24*60),3))]
    t =  np.linspace(0,(24*60),(24*60)+1)
    
    # load parameter draws for the two models
    pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
    pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))
    
    # Simulation of the system for the two models and extract of results
    solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
    solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')
    
    RFP_M1 = solM1[:,0:len(pM1[:,1])]
    GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]
    
    RFP_M2 = solM2[:,0:len(pM2[:,1])]
    GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]
    
    # Gaussian Process Regression and Reduction
    
    # Means and standard deviations for each time point for each species and for each model
    tgp = np.linspace(0,(24*60),round(24*60/5)+1)
    
    muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
    sdR3 = RFP_M2.std(axis = 1)
    muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
    sdG3 = GFP_M2.std(axis = 1)
    muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
    sdR2 = RFP_M1.std(axis = 1)
    muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
    sdG2 = GFP_M1.std(axis = 1)

    # Gaussian Process regression
    gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
    gR3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gR3.predict(tgp)
    
    gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
    gG3.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG3.predict(tgp)
    
    gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
    gR2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gR2.predict(tgp)
    
    gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
    gG2.findhyperparameters(noruns=15, optmessages = False, quiet = True)
    gG2.predict(tgp)
    
    # Time points reduction

    muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
    tref = list(tgp[::10])

    g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2R3.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
    tref = list(tgp[::10])

    g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2R2.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
    tref = list(tgp[::10])

    g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G3.predict(tref)

    
    muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
    tref = list(tgp[::10])

    
    g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
    g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
    g2G2.predict(tref)

    
    # Bhattacharyya distance:
    bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
    bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
    
    # Check for too flat reagions that give numerical instability
    if bdR == float("inf") or bdG == float("inf"):
        nwar = []
        nwar1 = textract(gR3.mnp, gR3.covp)
        nwar2 = textract(gR2.mnp, gR2.covp)

        if len(np.asarray(nwar1).reshape(-1,1)) <= len(np.asarray(nwar2).reshape(-1,1)):
            nwar = nwar1
        else:
            nwar = nwar2

        muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
        tref = list(tgp[::10])


        n = 0
        for u in np.asarray(nwar).reshape(-1,1):
            del muref[int(u)-n]
            del tref[int(u)-n]
            n +=1

        # muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
        # tref = list(tgp[::10])

        g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
        g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
        g2R3.predict(tref)

        muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
        tref = list(tgp[::10])

        n = 0
        for u in np.asarray(nwar).reshape(-1,1):
            del muref[int(u)-n]
            del tref[int(u)-n]
            n +=1




        g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
        g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
        g2R2.predict(tref)

        print(nwar)

        nwar = []
        nwar1 = textract(gG3.mnp, gG3.covp)
        nwar2 = textract(gG2.mnp, gG2.covp)

        if len(np.asarray(nwar1).reshape(-1,1)) <= len(np.asarray(nwar2).reshape(-1,1)):
            nwar = nwar1
        else:
            nwar = nwar2

        muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
        tref = list(tgp[::10])

        n = 0
        for u in np.asarray(nwar).reshape(-1,1):
            del muref[int(u)-n]
            del tref[int(u)-n]
            n +=1

        g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
        g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
        g2G3.predict(tref)


        muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
        tref = list(tgp[::10])

        n = 0
        for u in np.asarray(nwar).reshape(-1,1):
            del muref[int(u)-n]
            del tref[int(u)-n]
            n +=1

        g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
        g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
        g2G2.predict(tref)
        
        bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
        bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
    
    # Utility function value
    u_B = (bdR+bdG)/2

    return(u_B)

# %% [markdown]
# ### Bayesian Optimisation:

# %%
# Bounded region of parameter space

pbounds = {'IPTG1': (0, 1), 'IPTG2': (0, 1),
           'aTc1': (0, 100), 'aTc2': (0, 100)}

# %% [markdown]
# Setting Bayesian Optimisation with our utility function

# %%
optimizer3 = BayesianOptimization(
    f=utility2,
    pbounds=pbounds,
    verbose=2, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1324,
)

# %% [markdown]
# Begin optimisation rutine

# %%
optimizer3.maximize(
    init_points=0,
    n_iter=400,
    alpha=1e-2,
    n_restarts_optimizer=3, 
#     acq="ei", 
#     xi=1e-4
)
# Out:
# |   iter    |  target   |   IPTG1   |   IPTG2   |   aTc1    |   aTc2    |
# -------------------------------------------------------------------------
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 2
# |  405      |  3.102e+0 |  0.8163   |  0.426    |  24.08    |  14.95    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
# |  406      |  7.718e+0 |  0.9176   |  0.2478   |  24.92    |  15.39    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 6
# |  407      |  1.46e+06 |  0.9273   |  0.3117   |  24.38    |  15.66    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 11
# |  408      |  1.139e+0 |  0.7612   |  0.3544   |  25.09    |  15.41    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
# |  409      |  1.307e+0 |  0.453    |  0.1327   |  24.89    |  15.13    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
# |  410      |  5.306e+0 |  0.4097   |  0.1992   |  24.82    |  15.59    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
# |  411      |  1.099e+0 |  0.4458   |  0.244    |  24.87    |  15.24    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
# |  412      |  1.867e+0 |  0.9518   |  0.3452   |  25.22    |  15.14    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
# |  413      |  6.983e+0 |  0.7126   |  0.8586   |  25.2     |  15.31    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
# |  414      |  1.077e+0 |  0.9912   |  0.3441   |  24.69    |  15.09    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
# |  415      |  8.403e+0 |  0.8382   |  0.2942   |  24.39    |  15.04    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 1
# |  416      |  3.611e+0 |  0.9556   |  0.4109   |  24.99    |  15.22    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
# |  417      |  8.477e+0 |  0.9438   |  0.2479   |  24.44    |  15.72    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 8
# |  418      |  1.517e+0 |  0.848    |  0.4618   |  24.63    |  15.21    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 2
# |  419      |  7.075e+0 |  0.602    |  0.1745   |  25.41    |  15.23    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
# |  420      |  5.96e+05 |  0.8951   |  0.2411   |  24.12    |  15.51    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 15
# |  421      |  3.699e+0 |  0.9984   |  0.3679   |  24.29    |  15.22    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
# |  422      |  5.987e+0 |  0.588    |  0.1268   |  24.55    |  15.45    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
# |  423      |  4.121e+0 |  0.9719   |  0.1952   |  25.2     |  15.21    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 12
# |  424      |  8.014e+0 |  0.2323   |  0.06235  |  24.63    |  15.37    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 14
# |  425      |  1.179e+0 |  0.8211   |  0.3004   |  24.82    |  14.95    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 10
# |  426      |  3.288e+0 |  0.8273   |  0.224    |  24.3     |  15.42    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 1
# |  427      |  2.014e+0 |  0.3957   |  0.263    |  24.56    |  15.53    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 6
# |  428      |  1.654e+0 |  0.8995   |  0.5234   |  25.17    |  15.05    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
# |  429      |  6.169e+0 |  0.2841   |  0.1212   |  24.24    |  15.38    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 6
# |  430      |  1.683e+0 |  0.8443   |  0.4456   |  24.17    |  15.03    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
# |  431      |  1.469e+0 |  0.9594   |  0.3278   |  24.43    |  15.5     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 14
# |  432      |  8.791e+0 |  0.3305   |  0.2064   |  25.06    |  15.86    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 9
# |  433      |  1.299e+0 |  0.9434   |  0.1351   |  24.9     |  15.4     |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 14
# |  434      |  2.982e+0 |  0.2093   |  0.02412  |  24.87    |  15.05    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 14
# |  435      |  1.457e+0 |  0.4365   |  0.2306   |  24.53    |  15.55    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
# |  436      |  5.955e+0 |  0.2521   |  0.04744  |  24.78    |  15.22    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 12
# |  437      |  1.423e+0 |  0.8703   |  0.3284   |  24.61    |  15.07    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
# |  438      |  2.712e+0 |  0.3551   |  0.2175   |  24.36    |  15.48    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 9
# |  439      |  3.562e+0 |  0.5083   |  0.4209   |  24.52    |  15.45    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
# |  440      |  1.097e+0 |  0.9946   |  0.3268   |  24.55    |  15.06    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
# |  441      |  2.17e+06 |  0.5597   |  0.2515   |  24.48    |  15.52    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 12
# |  442      |  1.666e+0 |  0.3846   |  0.2689   |  24.88    |  15.2     |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 14
# |  443      |  8.846e+0 |  0.7568   |  0.3881   |  24.3     |  15.18    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
# |  444      |  1.081e+0 |  0.4847   |  0.1155   |  25.29    |  15.19    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 13
# |  445      |  1.479e+0 |  0.4034   |  0.4531   |  24.65    |  15.48    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 4
# |  446      |  2.938e+0 |  0.5428   |  0.2481   |  24.39    |  15.47    |
#  Warning: optimization failed at run 7
# |  447      |  2.944e+0 |  0.4308   |  0.05023  |  24.31    |  15.36    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  448      |  1.701e+0 |  0.5099   |  0.7132   |  24.15    |  15.2     |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
# |  449      |  1.778e+0 |  0.5521   |  0.6014   |  24.19    |  15.19    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 8
# |  450      |  2.178e+0 |  0.8668   |  0.3907   |  24.8     |  15.53    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
# |  451      |  8.006e+0 |  0.4704   |  0.1004   |  24.86    |  15.23    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
# |  452      |  4.012e+0 |  0.3547   |  0.1261   |  24.69    |  15.19    |
#  Warning: optimization failed at run 9
# |  453      |  1.887e+0 |  0.6305   |  0.6475   |  25.12    |  14.98    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
# |  454      |  8.786e+0 |  0.6461   |  0.298    |  24.65    |  15.26    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 5
# |  455      |  2.871e+0 |  0.8212   |  0.2133   |  24.49    |  15.43    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
# |  456      |  2.845e+0 |  0.4172   |  0.5922   |  24.71    |  15.56    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
# |  457      |  1.049e+0 |  0.3219   |  0.3025   |  24.89    |  15.55    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
# |  458      |  1.738e+0 |  0.3235   |  0.1809   |  24.29    |  15.47    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 1
# |  459      |  6.001e+0 |  0.3853   |  0.1375   |  24.68    |  15.26    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 15
# |  460      |  1.882e+0 |  0.8303   |  0.3613   |  25.06    |  15.5     |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 11
# |  461      |  2.177e+0 |  0.6313   |  0.6566   |  24.25    |  15.11    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
# |  462      |  3.26e+06 |  0.3353   |  0.166    |  24.02    |  15.22    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 9
# |  463      |  3.424e+0 |  0.6848   |  0.2394   |  24.41    |  15.48    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
# |  464      |  1.738e+0 |  0.7849   |  0.7784   |  25.01    |  14.93    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  465      |  7.074e+0 |  0.8143   |  0.3796   |  25.03    |  15.0     |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 3
# |  466      |  1.126e+0 |  0.8602   |  0.3107   |  24.07    |  15.48    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
# |  467      |  1.751e+0 |  0.6283   |  0.6175   |  25.07    |  15.12    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
# |  468      |  9.902e+0 |  0.7798   |  0.346    |  25.17    |  15.4     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 5
# |  469      |  1.013e+0 |  0.9106   |  0.5594   |  25.08    |  15.6     |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
# |  470      |  2.048e+0 |  0.3931   |  0.09739  |  24.88    |  15.25    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 4
# |  471      |  7.704e+0 |  0.2552   |  0.261    |  24.52    |  15.22    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
# |  472      |  1.122e+0 |  0.5917   |  0.698    |  24.97    |  15.1     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
# |  473      |  1.141e+0 |  0.4824   |  0.2243   |  25.06    |  15.87    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
# |  474      |  8.494e+0 |  0.6211   |  0.2506   |  24.65    |  15.16    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 9
# |  475      |  6.734e+0 |  0.3789   |  0.03831  |  24.82    |  15.67    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  476      |  1.947e+0 |  0.3739   |  0.37     |  24.57    |  15.27    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
# |  477      |  2.739e+0 |  0.3757   |  0.1098   |  24.04    |  15.22    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 13
# |  478      |  2.174e+0 |  0.4738   |  0.1542   |  24.59    |  15.15    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 10
# |  479      |  3.996e+0 |  0.3953   |  0.2186   |  24.28    |  15.48    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 11
# |  480      |  1.213e+0 |  0.9908   |  0.2988   |  24.35    |  15.68    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
# |  481      |  2.238e+0 |  0.4753   |  0.05471  |  24.86    |  15.74    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 7
# |  482      |  5.804e+0 |  0.4279   |  0.09357  |  24.51    |  15.5     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 12
# |  483      |  6.193e+0 |  0.2857   |  0.2038   |  24.54    |  15.56    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
# |  484      |  1.047e+0 |  0.7138   |  0.8049   |  25.03    |  14.95    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
# |  485      |  1.235e+0 |  0.3676   |  0.3394   |  24.23    |  15.47    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 11
# |  486      |  4.505e+0 |  0.3784   |  0.1968   |  24.79    |  15.13    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
# |  487      |  1.472e+0 |  0.3444   |  0.2389   |  24.64    |  15.08    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 14
# |  488      |  6.801e+0 |  0.2505   |  0.2464   |  24.04    |  15.17    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
# |  489      |  1.341e+0 |  0.3301   |  0.3738   |  24.19    |  15.32    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
# |  490      |  1.357e+0 |  0.593    |  0.2944   |  25.06    |  15.89    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
# |  491      |  1.474e+0 |  0.9626   |  0.3733   |  24.2     |  15.49    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 8
# |  492      |  7.417e+0 |  0.8348   |  0.2798   |  24.83    |  15.42    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
# |  493      |  1.249e+0 |  0.9832   |  0.3323   |  24.86    |  15.49    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 14
# |  494      |  1.005e+0 |  0.9296   |  0.2726   |  24.25    |  15.31    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 2
# |  495      |  2.421e+0 |  0.3296   |  0.09659  |  24.0     |  15.24    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 12
# |  496      |  1.959e+0 |  0.8361   |  0.3765   |  25.12    |  15.18    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 3
# |  497      |  3.953e+0 |  0.2796   |  0.4409   |  24.57    |  15.29    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
# |  498      |  1.492e+0 |  0.908    |  0.4607   |  24.92    |  15.08    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 5
# |  499      |  7.944e+0 |  0.6307   |  0.2862   |  24.79    |  15.78    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
# |  500      |  1.474e+0 |  0.63     |  0.4806   |  24.3     |  14.89    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
# |  501      |  1.956e+0 |  0.88     |  0.4384   |  24.75    |  15.18    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 6
# |  502      |  2.018e+0 |  0.9131   |  0.3658   |  24.09    |  15.49    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
# |  503      |  1.644e+0 |  0.8914   |  0.3192   |  24.94    |  14.95    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
# |  504      |  5.173e+0 |  0.2229   |  0.3269   |  24.13    |  15.39    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 5
# |  505      |  2.054e+0 |  0.8026   |  0.3799   |  24.06    |  15.44    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 12
# |  506      |  2.152e+0 |  0.9381   |  0.3836   |  25.02    |  15.2     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
# |  507      |  2.155e+0 |  0.3217   |  0.1527   |  24.3     |  15.45    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
# |  508      |  1.781e+0 |  0.6945   |  0.5875   |  24.3     |  15.14    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 10
# |  509      |  8.214e+0 |  0.1978   |  0.1258   |  24.44    |  15.46    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
# |  510      |  7.367e+0 |  0.3008   |  0.1931   |  24.47    |  15.4     |
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
# |  511      |  4.554e+0 |  0.3826   |  0.1981   |  24.55    |  15.26    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 5
# |  512      |  3.868e+0 |  0.8764   |  0.8644   |  24.96    |  14.83    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 11
# |  513      |  7.055e+0 |  0.5771   |  0.178    |  24.68    |  15.13    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
# |  514      |  1.241e+0 |  0.5662   |  0.3065   |  25.23    |  15.25    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 15
# |  515      |  1.83e+05 |  0.8603   |  0.5205   |  24.62    |  15.28    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
# |  516      |  4.482e+0 |  0.3287   |  0.1339   |  23.97    |  15.22    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
# |  517      |  2.568e+0 |  0.5723   |  0.237    |  25.27    |  15.36    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 5
# |  518      |  1.436e+0 |  0.4626   |  0.2085   |  24.66    |  15.19    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 12
# |  519      |  7.856e+0 |  0.6069   |  0.1532   |  24.01    |  15.07    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 11
# |  520      |  1.23e+06 |  0.3333   |  0.396    |  23.85    |  15.13    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
# |  521      |  1.842e+0 |  0.4632   |  0.1931   |  24.68    |  15.08    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 14
# |  522      |  9.199e+0 |  0.8667   |  0.2946   |  24.57    |  15.06    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 1
# |  523      |  1.009e+0 |  0.5854   |  0.177    |  25.17    |  15.45    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
# |  524      |  2.316e+0 |  0.9834   |  0.4334   |  24.19    |  14.88    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 7
# |  525      |  1.033e+0 |  0.1683   |  0.01961  |  24.5     |  15.23    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 2
# |  526      |  2.718e+0 |  0.6869   |  0.6478   |  25.18    |  15.26    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 11
# |  527      |  4.145e+0 |  0.6049   |  0.4027   |  25.19    |  15.31    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 12
# |  528      |  8.697e+0 |  0.9556   |  0.2433   |  24.24    |  15.73    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
# |  529      |  8.317e+0 |  0.8604   |  0.839    |  25.08    |  15.07    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 13
# |  530      |  4.612e+0 |  0.3826   |  0.1582   |  24.76    |  14.98    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 13
# |  531      |  2.497e+0 |  0.3765   |  0.2617   |  23.76    |  15.04    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
# |  532      |  2.089e+0 |  0.8695   |  0.3778   |  24.86    |  15.57    |
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 1
# |  533      |  1.218e+0 |  0.6014   |  0.2119   |  25.47    |  15.34    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
# ...
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 2
# |  768      |  2.131e+0 |  0.3325   |  0.1969   |  23.65    |  14.86    |
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 6
# |  769      |  4.981e+0 |  0.5706   |  0.1459   |  24.31    |  15.18    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 14
# |  770      |  7.785e+0 |  0.3143   |  0.007008 |  23.89    |  14.89    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
# |  771      |  6.821e+0 |  0.3865   |  0.4877   |  24.69    |  15.4     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 4
# |  772      |  2.406e+0 |  0.6458   |  0.8745   |  67.53    |  50.75    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 9
# |  773      |  8.735e+0 |  0.3057   |  0.06421  |  24.06    |  15.18    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 5
# |  774      |  1.459e+0 |  0.5632   |  0.2995   |  21.64    |  21.05    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 15
# |  775      |  1.581e+0 |  0.8269   |  0.3527   |  24.09    |  15.59    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 3
# |  776      |  1.809e+0 |  0.4874   |  0.2444   |  24.56    |  15.54    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
# |  777      |  1.108e+0 |  0.188    |  0.5151   |  95.65    |  30.04    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
# |  778      |  1.512e+0 |  0.5656   |  0.1568   |  25.16    |  14.93    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 12
# |  779      |  1.221e+0 |  0.8936   |  0.4847   |  24.21    |  15.02    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
# |  780      |  1.108e+0 |  0.6581   |  0.278    |  24.46    |  15.64    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  781      |  2.245e+0 |  0.8444   |  0.9979   |  26.73    |  68.78    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
# |  782      |  2.238e+0 |  0.3912   |  0.233    |  25.25    |  15.2     |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 7
# |  783      |  1.455e+0 |  0.1478   |  0.6196   |  18.76    |  43.69    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 11
# |  784      |  9.97e+05 |  0.331    |  0.0509   |  23.72    |  14.87    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
# |  785      |  2.104e+0 |  0.7481   |  0.5635   |  95.83    |  47.82    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 1
# |  786      |  1.229e+0 |  0.4967   |  0.1302   |  24.63    |  15.45    |
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 3
# |  787      |  1.68e+06 |  0.9393   |  0.4224   |  24.07    |  15.5     |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
# |  788      |  5.184e+0 |  0.6389   |  0.1009   |  25.08    |  15.19    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
# |  789      |  3.31e+06 |  0.3287   |  0.2      |  23.77    |  15.17    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 12
# |  790      |  3.62e+04 |  0.3282   |  0.6809   |  85.95    |  26.03    |
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 4
# |  791      |  2.346e+0 |  0.3701   |  0.09794  |  23.6     |  15.12    |
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
# |  792      |  1.182e+0 |  0.4447   |  0.8618   |  7.022    |  48.75    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
# |  793      |  1.169e+0 |  0.3112   |  0.08249  |  24.95    |  15.13    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 10
# |  794      |  6.993e+0 |  0.5947   |  0.1937   |  24.73    |  15.01    |
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 7
# |  795      |  3.168e+0 |  0.8418   |  0.4675   |  24.23    |  15.02    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 10
# |  796      |  1.931e+0 |  0.4181   |  0.5844   |  62.06    |  45.23    |
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
# |  797      |  7.891e+0 |  0.3856   |  0.1873   |  23.75    |  15.16    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 13
# |  798      |  2.969e+0 |  0.6946   |  0.3293   |  17.71    |  57.73    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 12
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 14
# |  799      |  1.239e+0 |  0.4912   |  0.5529   |  25.1     |  15.41    |
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 14
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 10
# |  800      |  1.343e+0 |  0.6068   |  0.4243   |  94.03    |  51.95    |
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 13
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 15
# |  801      |  1.839e+0 |  0.9996   |  0.6051   |  82.96    |  86.19    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 4
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 2
# |  802      |  2.588e+0 |  0.9806   |  0.424    |  24.98    |  14.88    |
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 9
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 6
#  Warning: optimization failed at run 2
# |  803      |  9.037e+0 |  0.4972   |  0.2558   |  24.95    |  14.83    |
#  Warning: optimization failed at run 1
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 7
#  Warning: optimization failed at run 10
#  Warning: optimization failed at run 11
#  Warning: optimization failed at run 15
#  Warning: optimization failed at run 3
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 5
#  Warning: optimization failed at run 8
#  Warning: optimization failed at run 2
#  Warning: optimization failed at run 5
# |  804      |  4.378e+0 |  0.251    |  0.2234   |  24.58    |  15.43    |
# =========================================================================

# %%
# Save results obtained
with open('config2sAverage2.optim', 'wb') as config_optim_file:
 
    pickle.dump(optimizer3, config_optim_file)

# %%
# Best utility value generated
print(optimizer3.max)
# Out:
# {'target': 7890753.079512517, 'params': {'IPTG1': 0.3855761411664625, 'IPTG2': 0.18732385084528325, 'aTc1': 23.75227126438877, 'aTc2': 15.162922133016473}}

# %% [markdown]
# Plot best utility value so far per iteration:

# %%
v = []
for i, res in enumerate(optimizer3.res):
    v.append(res['target'])
    
vn = []
for i, val in enumerate(v):
    mv = max(v[0:i+1])
    vn.append(mv)
    
plt.figure()
plt.plot(vn)
plt.plot(v)
plt.show()

# %%
df = pd.DataFrame({
    'CFV': v})
df.to_csv('CFV_Iter_2S_Average.csv')

df = pd.DataFrame({
    'CFV': vn})
df.to_csv('bestCFV_Iter_2S_Average.csv')

# %% [markdown]
# ### Check results with plot

# %%
inputs = [round(optimizer3.max['params']['IPTG1'], 2)+1e-7, int(optimizer3.max['params']['aTc1'])+1e-7, 
          round(optimizer3.max['params']['IPTG2'], 2)+1e-7, int(optimizer3.max['params']['aTc2'])+1e-7]

ivss = [1,1e-7,1363.193,28.510]
pre = [1,1e-7]
sp = [int(i) for i in list(np.linspace(0,(24*60),3))]
t =  np.linspace(0,(24*60),(24*60)+1)

pM1 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model1.stan.csv"))
pM2 = np.asarray(pd.read_csv("ParametersCSV/drawsRedT_ALL_Model2.stan.csv"))

# Simulation of the system for the two models and extract of results
solM1 = solveALL(t, pM1, sp, inputs, ivss, pre, 'M1')
solM2 = solveALL(t, pM2, sp, inputs, ivss, pre, 'M2')

RFP_M1 = solM1[:,0:len(pM1[:,1])]
GFP_M1 = solM1[:,len(pM1[:,1]):(len(pM1[:,1])*2)]

RFP_M2 = solM2[:,0:len(pM2[:,1])]
GFP_M2 = solM2[:,len(pM2[:,1]):(len(pM2[:,1])*2)]

# %%
t = np.linspace(0,(24*60),round(24*60/5)+1)

plt.figure()
lines = plt.plot(t, GFP_M2, 'c')
plt.text((24*60)+1, 800, "Model 2", bbox=dict(facecolor='c'))
plt.title("Average")
lines2 = plt.plot(t, GFP_M1, 'g')
plt.text((24*60)+1, 600, "Model 1", bbox=dict(facecolor='g'))

plt.show()
plt.figure()
plt.plot(t, RFP_M2, 'c')

plt.text((24*60)+1, 500, "Model 2", bbox=dict(facecolor='c'))
plt.text((24*60)+1, 40, "Model 1", bbox=dict(facecolor='r'))
plt.plot(t, RFP_M1, 'r')
plt.show()

# %% [markdown]
# ### Check utility decomposition results

# %%
# Gaussian Process Regression and Reduction

# Means and standard deviations for each time point for each species and for each model
tgp = np.linspace(0,(24*60),(24*60/5)+1)

muR3 = RFP_M2.mean(axis = 1) # Model 2, RFP
sdR3 = RFP_M2.std(axis = 1)
muG3 = GFP_M2.mean(axis = 1) # Model 2, GFP
sdG3 = GFP_M2.std(axis = 1)
muR2 = RFP_M1.mean(axis = 1) # Model 1, RFP
sdR2 = RFP_M1.std(axis = 1)
muG2 = GFP_M1.mean(axis = 1) # Model 1, GFP
sdG2 = GFP_M1.std(axis = 1)

# Gaussian Process regression
gR3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR3, (sdR3**2)) # RFP, Model 2
gR3.findhyperparameters(noruns=15)
gR3.predict(tgp)

gG3= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG3, (sdG3**2)) # GFP, Model 2
gG3.findhyperparameters(noruns=15)
gG3.predict(tgp)

gR2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muR2, (sdR2**2)) # RFP, Model 1
gR2.findhyperparameters(noruns=15)
gR2.predict(tgp)

gG2= gp.sqexpGP({0:(4, 10), 1: (-4, -2), 2: (-3,-1)}, tgp, muG2, (sdG2**2)) # GFP, Model 1
gG2.findhyperparameters(noruns=15)
gG2.predict(tgp)

# %%
muref = list(np.matrix.transpose((np.random.multivariate_normal(gR3.mnp, gR3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gR2.mnp, gR2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2R2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2R2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2R2.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG3.mnp, gG3.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G3= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G3.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G3.predict(tref)

muref = list(np.matrix.transpose((np.random.multivariate_normal(gG2.mnp, gG2.covp, 2000)))[::10])
tref = list(tgp[::10])

g2G2= gp.sqexpGP({0:(4, 10), 1: (-6, -3), 2: (1,4)}, tref, np.asarray(muref).mean(axis=1), np.asarray(muref).std(axis=1)**2)
g2G2.findhyperparameters(noruns=15, optmessages = True, quiet = True)
g2G2.predict(tref)

# %%
bdR = BhattacharyyaDist(g2R3.mnp, g2R2.mnp, g2R3.covp, g2R2.covp)
bdG = BhattacharyyaDist(g2G3.mnp, g2G2.mnp, g2G3.covp, g2G2.covp)
u_B = (bdR+bdG)/2

# %%
print("The BD for RFP is: ", str(bdR))
print("The BD for GFP is: ", str(bdG))
print("The average BD is: ", str(u_B))
